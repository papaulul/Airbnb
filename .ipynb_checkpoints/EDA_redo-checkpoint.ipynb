# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

pd.options.display.max_columns = None

try:
	os.chdir(os.path.join(os.getcwd(), '../2019 Spring/SpringAccel'))
	print(os.getcwd())
except:
	pass

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

pd.options.display.max_columns = None

try:
	os.chdir(os.path.join(os.getcwd(), '../2019 Spring/SpringAccel'))
	print(os.getcwd())
except:
	pass

# %%
#Read in dataset 
#df = pd.read_csv('Airbnb_Listing_with_242Plus.csv',index_col = 0)
df = pd.read_csv('AirbnbWithMorePlus.csv',index_col = 1)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (18,21,29,34,35,45,55,63,64,67,69,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#          id                        listing_url     scrape_id last_scraped  \
# 0.0   109.0   https://www.airbnb.com/rooms/109  2.018121e+13   2018-12-07
# 1.0   344.0   https://www.airbnb.com/rooms/344  2.018121e+13   2018-12-07
# 2.0  2708.0  https://www.airbnb.com/rooms/2708  2.018121e+13   2018-12-06
# 3.0  2732.0  https://www.airbnb.com/rooms/2732  2.018121e+13   2018-12-06
# 4.0  2864.0  https://www.airbnb.com/rooms/2864  2.018121e+13   2018-12-06
#
#                                                   name  \
# 0.0  Amazing bright elegant condo park front *UPGRA...
# 1.0                  Family perfect;Pool;Near Studios!
# 2.0  Gold Memory Foam Bed & Breakfast in West Holly...
# 3.0                              Zen Life at the Beach
# 4.0  *Upscale Professional Home with Beautiful Studio*
#
#                                                summary  \
# 0.0  *** Unit upgraded with new bamboo flooring, br...
# 1.0  This home is perfect for families; aspiring ch...
# 2.0  Our best memory foam pillows you'll ever sleep...
# 3.0                                                NaN
# 4.0  Centrally located.... Furnished with 42 inch S...
#
#                                                  space  \
# 0.0  *** Unit upgraded with new bamboo flooring, br...
# 1.0  Cheerful & comfortable; near studios, amusemen...
# 2.0  Flickering fireplace display heater.  Decorate...
# 3.0  This is a three story townhouse with the follo...
# 4.0  The space is furnished with Thomasville furnit...
#
#                                            description experiences_offered  \
# 0.0  *** Unit upgraded with new bamboo flooring, br...                none
# 1.0  This home is perfect for families; aspiring ch...                none
# 2.0  Our best memory foam pillows you'll ever sleep...                none
# 3.0  This is a three story townhouse with the follo...                none
# 4.0  Centrally located.... Furnished with 42 inch S...                none
#
#                                  neighborhood_overview  \
# 0.0                                                NaN
# 1.0  Quiet-yet-close to all the fun in LA! Hollywoo...
# 2.0  We are minutes away from the Mentor Language I...
# 3.0                                                NaN
# 4.0  What makes the neighborhood unique is that the...
#
#                                                  notes  \
# 0.0                                                NaN
# 1.0  One dog may be on premises, friendly and cared...
# 2.0  Decorated for the Holidays. Blendtec® Designer...
# 3.0                                                NaN
# 4.0  If you are doing business travel, this studio ...
#
#                                                transit  \
# 0.0                                                NaN
# 1.0  Short drive to subway and elevated trains runn...
# 2.0  There are many buses; bus stops going in every...
# 3.0                                                NaN
# 4.0  Public transportation is a 3 minutes walk to t...
#
#                                                 access  \
# 0.0                                                NaN
# 1.0  Pool, patio and self-contained main house all ...
# 2.0  Kitchen with new refrigerator, dishwasher, sto...
# 3.0                                                NaN
# 4.0  Good access to all things in Los Angeles and O...
#
#                                            interaction  \
# 0.0                                                NaN
# 1.0  Host and caretaker may be available throughout...
# 2.0  I am friendly and available to help you with y...
# 3.0                                                NaN
# 4.0  I am always available for questions throughout...
#
#                                            house_rules  thumbnail_url  \
# 0.0  Camelot NEW RESIDENTS’ GENERAL INFORMATION   F...            NaN
# 1.0  Host asks that guests refrain from partying lo...            NaN
# 2.0  I just have one rule. The Golden Rule Do unto ...            NaN
# 3.0  ABOUT YOU.  Friendly travelers or people comin...            NaN
# 4.0                                                NaN            NaN
#
#     medium_url                                        picture_url  \
# 0.0        NaN  https://a0.muscache.com/im/pictures/4321499/1d...
# 1.0        NaN  https://a0.muscache.com/im/pictures/cc4b724d-d...
# 2.0        NaN  https://a0.muscache.com/im/pictures/40618141/2...
# 3.0        NaN  https://a0.muscache.com/im/pictures/1082974/0f...
# 4.0        NaN  https://a0.muscache.com/im/pictures/23817858/d...
#
#      xl_picture_url host_id                                host_url  \
# 0.0             NaN     521   https://www.airbnb.com/users/show/521
# 1.0             NaN     767   https://www.airbnb.com/users/show/767
# 2.0             NaN    3008  https://www.airbnb.com/users/show/3008
# 3.0             NaN    3041  https://www.airbnb.com/users/show/3041
# 4.0             NaN    3207  https://www.airbnb.com/users/show/3207
#
#           host_name  host_since                             host_location  \
# 0.0           Paolo  2008-06-27  San Francisco, California, United States
# 1.0         Melissa  2008-07-11        Burbank, California, United States
# 2.0           Chas.  2008-09-16    Los Angeles, California, United States
# 3.0  Yoga Priestess  2008-09-17   Santa Monica, California, United States
# 4.0       Bernadine  2008-09-25     Long Beach, California, United States
#
#                                             host_about  host_response_time  \
# 0.0  Search for me on the Internet with the keyword...                 NaN
# 1.0  Single mother, CEO and Owner of an internation...        within a day
# 2.0  Writer.\r\nLiterary Manager.\r\nPhotographer.\...      within an hour
# 3.0  I have been teaching yoga and meditation for 3...  within a few hours
# 4.0  Fair, open, honest and very informative for ne...                 NaN
#
#     host_response_rate host_acceptance_rate host_is_superhost  \
# 0.0                NaN                  NaN                 f
# 1.0               100%                  NaN                 f
# 2.0               100%                  NaN                 t
# 3.0               100%                  NaN                 f
# 4.0                NaN                  NaN                 f
#
#                                     host_thumbnail_url  \
# 0.0  https://a0.muscache.com/im/users/521/profile_p...
# 1.0  https://a0.muscache.com/im/users/767/profile_p...
# 2.0  https://a0.muscache.com/im/pictures/user/d17cf...
# 3.0  https://a0.muscache.com/im/users/3041/profile_...
# 4.0  https://a0.muscache.com/im/pictures/8b82a267-b...
#
#                                       host_picture_url host_neighbourhood  \
# 0.0  https://a0.muscache.com/im/users/521/profile_p...        Culver City
# 1.0  https://a0.muscache.com/im/users/767/profile_p...            Burbank
# 2.0  https://a0.muscache.com/im/pictures/user/d17cf...          Hollywood
# 3.0  https://a0.muscache.com/im/users/3041/profile_...       Santa Monica
# 4.0  https://a0.muscache.com/im/pictures/8b82a267-b...         Bellflower
#
#     host_listings_count host_total_listings_count  \
# 0.0                   1                         1
# 1.0                   1                         1
# 2.0                   2                         2
# 3.0                   2                         2
# 4.0                   1                         1
#
#                                     host_verifications host_has_profile_pic  \
# 0.0   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 1.0  ['email', 'phone', 'reviews', 'jumio', 'kba', ...                    t
# 2.0   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 3.0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 4.0              ['email', 'phone', 'facebook', 'kba']                    t
#
#     host_identity_verified                           street neighbourhood  \
# 0.0                      t   Culver City, CA, United States   Culver City
# 1.0                      t       Burbank, CA, United States       Burbank
# 2.0                      t   Los Angeles, CA, United States           NaN
# 3.0                      f  Santa Monica, CA, United States  Santa Monica
# 4.0                      t    Bellflower, CA, United States    Bellflower
#
#     neighbourhood_cleansed  neighbourhood_group_cleansed          city state  \
# 0.0            Culver City                           NaN   Culver City    CA
# 1.0                Burbank                           NaN       Burbank    CA
# 2.0              Hollywood                           NaN   Los Angeles    CA
# 3.0           Santa Monica                           NaN  Santa Monica    CA
# 4.0             Bellflower                           NaN    Bellflower    CA
#
#     zipcode       market    smart_location country_code        country  \
# 0.0   90230  Los Angeles   Culver City, CA           US  United States
# 1.0   91505  Los Angeles       Burbank, CA           US  United States
# 2.0   90046  Los Angeles   Los Angeles, CA           US  United States
# 3.0   90405  Los Angeles  Santa Monica, CA           US  United States
# 4.0   90706  Los Angeles    Bellflower, CA           US  United States
#
#       latitude   longitude is_location_exact property_type        room_type  \
# 0.0  33.982095 -118.384935                 t   Condominium  Entire home/apt
# 1.0  34.165616 -118.334582                 t         House  Entire home/apt
# 2.0  34.097676 -118.346023                 t     Apartment     Private room
# 3.0  34.004750 -118.481266                 t     Apartment     Private room
# 4.0  33.876189 -118.113968                 t     Apartment  Entire home/apt
#
#     accommodates  bathrooms  bedrooms  beds       bed_type  \
# 0.0            6        2.0       2.0   3.0       Real Bed
# 1.0            6        1.0       3.0   3.0       Real Bed
# 2.0            1        1.5       1.0   1.0       Real Bed
# 3.0            1        1.0       1.0   1.0  Pull-out Sofa
# 4.0            2        1.0       1.0   1.0       Real Bed
#
#                                              amenities  square_feet    price  \
# 0.0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $122.00
# 1.0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $168.00
# 2.0  {Internet,Wifi,"Air conditioning","Wheelchair ...          NaN   $79.00
# 3.0  {Internet,Wifi,Kitchen,Heating,Washer,Dryer,"S...          NaN  $140.00
# 4.0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN   $80.00
#
#     weekly_price monthly_price security_deposit cleaning_fee guests_included  \
# 0.0      $904.00     $2,851.00          $500.00      $240.00               3
# 1.0          NaN           NaN            $0.00      $100.00               6
# 2.0      $399.00       $949.00          $299.00       $85.00               1
# 3.0      $800.00     $1,879.00              NaN      $100.00               1
# 4.0      $399.00     $1,400.00          $100.00       $75.00               1
#
#     extra_people minimum_nights maximum_nights calendar_updated  \
# 0.0       $25.00              7            730     9 months ago
# 1.0        $0.00              2             14       4 days ago
# 2.0        $0.00              6            366            today
# 3.0        $0.00              1            180      4 weeks ago
# 4.0       $25.00              2            730     4 months ago
#
#     has_availability  availability_30  availability_60  availability_90  \
# 0.0                t              0.0              0.0              0.0
# 1.0                t              0.0              0.0              0.0
# 2.0                t              0.0              0.0              6.0
# 3.0                t             25.0             55.0             85.0
# 4.0                t              0.0              0.0              0.0
#
#      availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0.0             236.0            2018-12-07                2.0   2011-08-15
# 1.0             135.0            2018-12-07                4.0   2016-06-14
# 2.0             260.0            2018-12-06               13.0   2014-06-09
# 3.0             360.0            2018-12-06               18.0   2011-06-06
# 4.0               0.0            2018-12-06                0.0          NaN
#
#     last_review  review_scores_rating  review_scores_accuracy  \
# 0.0  2016-05-15                  80.0                    10.0
# 1.0  2018-10-21                  93.0                    10.0
# 2.0  2018-09-07                  97.0                    10.0
# 3.0  2018-11-15                  96.0                     9.0
# 4.0         NaN                   NaN                     NaN
#
#      review_scores_cleanliness  review_scores_checkin  \
# 0.0                       10.0                    6.0
# 1.0                       10.0                   10.0
# 2.0                       10.0                   10.0
# 3.0                        9.0                   10.0
# 4.0                        NaN                    NaN
#
#      review_scores_communication  review_scores_location  review_scores_value  \
# 0.0                          8.0                    10.0                  8.0
# 1.0                         10.0                    10.0                  9.0
# 2.0                         10.0                    10.0                 10.0
# 3.0                         10.0                    10.0                  9.0
# 4.0                          NaN                     NaN                  NaN
#
#     requires_license license             jurisdiction_names instant_bookable  \
# 0.0                f     NaN          {"Culver City"," CA"}                f
# 1.0                f     NaN                            NaN                t
# 2.0                f     NaN  {"City of Los Angeles"," CA"}                t
# 3.0                t  228269               {"Santa Monica"}                f
# 4.0                f     NaN                            NaN                f
#
#     is_business_travel_ready          cancellation_policy  \
# 0.0                        f  strict_14_with_grace_period
# 1.0                        f                     flexible
# 2.0                        f  strict_14_with_grace_period
# 3.0                        f  strict_14_with_grace_period
# 4.0                        f  strict_14_with_grace_period
#
#     require_guest_profile_picture require_guest_phone_verification  \
# 0.0                             t                                f
# 1.0                             f                                f
# 2.0                             f                                f
# 3.0                             f                                f
# 4.0                             f                                f
#
#      calculated_host_listings_count  reviews_per_month  isPlus_x  \
# 0.0                             1.0               0.02       0.0
# 1.0                             1.0               0.13       0.0
# 2.0                             2.0               0.24       0.0
# 3.0                             2.0               0.20       0.0
# 4.0                             1.0                NaN       0.0
#
#                                                    uid  isPlus_y
# 0.0  Paolo|Amazing bright elegant condo park front ...       NaN
# 1.0          Melissa|Family perfect;Pool;Near Studios!       NaN
# 2.0  Chas.|Gold Memory Foam Bed & Breakfast in West...       NaN
# 3.0               Yoga Priestess|Zen Life at the Beach       NaN
# 4.0  Bernadine|*Upscale Professional Home with Beau...       NaN

# %%
df.rename({'isPlus_y': 'isPlus'}, axis=1,inplace=True)

df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month', 'isPlus_x',
#        'uid', 'isPlus'],
#       dtype='object')

# %%
# creates new popluation where it's either Plus listings or Superhost listings
population = df[(df['isPlus'] == 1) | (df['host_is_superhost'] == 't')]

# %%
population  = population.reset_index().drop(columns='index')

# %%
# type corrections 
population['host_total_listings_count'] = population['host_total_listings_count'].astype(float)
population['host_listings_count']=population['host_listings_count'].astype(float)
population['accommodates']=population['accommodates'].astype(float)

rest = ['guests_included','minimum_nights','maximum_nights']
for i in rest: 
    population[i] = population[i].astype(float)
    
money = ['price','weekly_price','monthly_price','security_deposit','cleaning_fee','extra_people']
population['price']=population['price'].apply(lambda x: float("".join(list(x)[1:]).replace(',',"")))
population['weekly_price'] = population['weekly_price'].apply(lambda x: 0 if str(x)[:1] != "$" else x)
population['weekly_price']=population['weekly_price'].apply(lambda x: float(str(x)[1:].replace(',',"")) if len(str(x))>1 else float(0) )
money = ['monthly_price','security_deposit','cleaning_fee','extra_people']
for i in money:    
    population[i]=population[i].apply(lambda x: 0 if str(x)[:1] != "$" else x)
for i in money: 
    population[i]=population[i].apply(lambda x: float(str(x)[1:].replace(',',"")) if len(str(x))>1 else float(0) )

# %%
# Making response rate into a float
population['host_response_rate']=population['host_response_rate'].apply(lambda x: float(str(x)[0:-1])/100 if str(x)[0:-1] != 'na' else np.NAN)

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11425 entries, 0 to 11424
# Data columns (total 99 columns):
# id                                  11425 non-null float64
# listing_url                         11425 non-null object
# scrape_id                           11425 non-null float64
# last_scraped                        11425 non-null object
# name                                11425 non-null object
# summary                             11214 non-null object
# space                               9867 non-null object
# description                         11366 non-null object
# experiences_offered                 11425 non-null object
# neighborhood_overview               8993 non-null object
# notes                               7507 non-null object
# transit                             8609 non-null object
# access                              8934 non-null object
# interaction                         8751 non-null object
# house_rules                         9227 non-null object
# thumbnail_url                       0 non-null float64
# medium_url                          0 non-null object
# picture_url                         11425 non-null object
# xl_picture_url                      0 non-null float64
# host_id                             11425 non-null object
# host_url                            11425 non-null object
# host_name                           11425 non-null object
# host_since                          11425 non-null object
# host_location                       11404 non-null object
# host_about                          8743 non-null object
# host_response_time                  9776 non-null object
# host_response_rate                  9776 non-null float64
# host_acceptance_rate                0 non-null object
# host_is_superhost                   11425 non-null object
# host_thumbnail_url                  11425 non-null object
# host_picture_url                    11425 non-null object
# host_neighbourhood                  9821 non-null object
# host_listings_count                 11425 non-null float64
# host_total_listings_count           11425 non-null float64
# host_verifications                  11425 non-null object
# host_has_profile_pic                11425 non-null object
# host_identity_verified              11425 non-null object
# street                              11425 non-null object
# neighbourhood                       10602 non-null object
# neighbourhood_cleansed              11425 non-null object
# neighbourhood_group_cleansed        0 non-null float64
# city                                11420 non-null object
# state                               11424 non-null object
# zipcode                             11294 non-null object
# market                              11410 non-null object
# smart_location                      11425 non-null object
# country_code                        11425 non-null object
# country                             11425 non-null object
# latitude                            11425 non-null float64
# longitude                           11425 non-null float64
# is_location_exact                   11425 non-null object
# property_type                       11425 non-null object
# room_type                           11425 non-null object
# accommodates                        11425 non-null float64
# bathrooms                           11421 non-null float64
# bedrooms                            11421 non-null float64
# beds                                11423 non-null float64
# bed_type                            11425 non-null object
# amenities                           11425 non-null object
# square_feet                         114 non-null float64
# price                               11425 non-null float64
# weekly_price                        11425 non-null float64
# monthly_price                       11425 non-null float64
# security_deposit                    11425 non-null float64
# cleaning_fee                        11425 non-null float64
# guests_included                     11425 non-null float64
# extra_people                        11425 non-null float64
# minimum_nights                      11425 non-null float64
# maximum_nights                      11425 non-null float64
# calendar_updated                    11425 non-null object
# has_availability                    11425 non-null object
# availability_30                     11425 non-null float64
# availability_60                     11425 non-null float64
# availability_90                     11425 non-null float64
# availability_365                    11425 non-null float64
# calendar_last_scraped               11425 non-null object
# number_of_reviews                   11425 non-null float64
# first_review                        10782 non-null object
# last_review                         10782 non-null object
# review_scores_rating                10776 non-null float64
# review_scores_accuracy              10775 non-null float64
# review_scores_cleanliness           10775 non-null float64
# review_scores_checkin               10771 non-null float64
# review_scores_communication         10773 non-null float64
# review_scores_location              10771 non-null float64
# review_scores_value                 10771 non-null float64
# requires_license                    11425 non-null object
# license                             372 non-null object
# jurisdiction_names                  7965 non-null object
# instant_bookable                    11425 non-null object
# is_business_travel_ready            11425 non-null object
# cancellation_policy                 11425 non-null object
# require_guest_profile_picture       11425 non-null object
# require_guest_phone_verification    11425 non-null object
# calculated_host_listings_count      11425 non-null float64
# reviews_per_month                   10782 non-null float64
# isPlus_x                            11425 non-null float64
# uid                                 11425 non-null object
# isPlus                              273 non-null float64
# dtypes: float64(40), object(59)
# memory usage: 8.6+ MB

# %%
# Looking at categorical columns 
cat = population.select_dtypes(include = 'object').copy()

# %%
cat.head()
# Out:
#                          listing_url last_scraped  \
# 0  https://www.airbnb.com/rooms/2708   2018-12-06
# 1  https://www.airbnb.com/rooms/6931   2018-12-06
# 2  https://www.airbnb.com/rooms/7143   2018-12-07
# 3  https://www.airbnb.com/rooms/7992   2018-12-07
# 4  https://www.airbnb.com/rooms/8021   2018-12-06
#
#                                                 name  \
# 0  Gold Memory Foam Bed & Breakfast in West Holly...
# 1  Off Sunset Wrap-Around Terr Runyon Canyon View...
# 2                 15min from anywhere in Los Angeles
# 3  Cozy Cottage/Home Away from Home/Close2Attract...
# 4                         5-Star Beverly Hills Suite
#
#                                              summary  \
# 0  Our best memory foam pillows you'll ever sleep...
# 1  Our best memory foam pillows; you'll ever slee...
# 2  Relax in LA  at this quiet, quaint and comfy p...
# 3  All the comforts of home in this charming furn...
# 4  This extraordinary apartment is a huge well-ap...
#
#                                                space  \
# 0  Flickering fireplace display heater.  Decorate...
# 1  Decorated with fresh flowers for the Holidays....
# 2  Great location!  15 min drive to beaches, Holl...
# 3  Please inquire about dates before booking.   Q...
# 4  This well-appointed guest room has a firm comf...
#
#                                          description experiences_offered  \
# 0  Our best memory foam pillows you'll ever sleep...                none
# 1  Our best memory foam pillows; you'll ever slee...                none
# 2  Relax in LA  at this quiet, quaint and comfy p...                none
# 3  All the comforts of home in this charming furn...                none
# 4  This extraordinary apartment is a huge well-ap...                none
#
#                                neighborhood_overview  \
# 0  We are minutes away from the Mentor Language I...
# 1  We are in the middle of one of the great citie...
# 2  Our neighborhood is walkable to green parks, a...
# 3  The myriad of great shops and restaurants with...
# 4  I love this area because it's safe and conveni...
#
#                                                notes  \
# 0  Decorated for the Holidays. Blendtec® Designer...
# 1  Decorated for the Holidays. Blendtec® Designer...
# 2                                                NaN
# 3  Driveway parking can be arranged and there is ...
# 4  I have a Cocker Spaniel goof-ball and a small ...
#
#                                              transit  \
# 0  There are many buses; bus stops going in every...
# 1  Buses are within a half a block away that go i...
# 2  Public transportation is very accessible. We a...
# 3  If you are flying into LAX and you arrive betw...
# 4  Most use Lyft or Uber to get around. Between r...
#
#                                               access  \
# 0  Kitchen with new refrigerator, dishwasher, sto...
# 1  Full use of the kitchen for light cooking and ...
# 2  The place has a full kitchen, bath and entranc...
# 3  Wifi, laundry facilities (included), gated bac...
# 4  I am not at all territorial and have indicated...
#
#                                          interaction  \
# 0  I am friendly and available to help you with y...
# 1  I am in the entertainment industry and wear ma...
# 2                                                NaN
# 3  Frequently and as much as needed.   We live on...
# 4  As much or as little as you'd like. I can trea...
#
#                                          house_rules medium_url  \
# 0  I just have one rule. The Golden Rule Do unto ...        NaN
# 1  There is a 300.00 key/stain deposit.  We use a...        NaN
# 2            NO Smoking, NO pets, NO parties please.        NaN
# 3  Be awesome. Be comfortable. Be happy! We ask t...        NaN
# 4  Come.  Stay.  Relax.  Enjoy all that Los Angel...        NaN
#
#                                          picture_url host_id  \
# 0  https://a0.muscache.com/im/pictures/40618141/2...    3008
# 1  https://a0.muscache.com/im/pictures/37075487/5...    3008
# 2  https://a0.muscache.com/im/pictures/d86b8b60-2...   18122
# 3  https://a0.muscache.com/im/pictures/f02c5f94-f...   22363
# 4  https://a0.muscache.com/im/pictures/55312183/4...   22460
#
#                                   host_url                host_name  \
# 0   https://www.airbnb.com/users/show/3008                    Chas.
# 1   https://www.airbnb.com/users/show/3008                    Chas.
# 2  https://www.airbnb.com/users/show/18122  Leilani & Ova & Nouthak
# 3  https://www.airbnb.com/users/show/22363                      Tom
# 4  https://www.airbnb.com/users/show/22460                     Sher
#
#    host_since                             host_location  \
# 0  2008-09-16    Los Angeles, California, United States
# 1  2008-09-16    Los Angeles, California, United States
# 2  2009-05-20    Los Angeles, California, United States
# 3  2009-06-19    Los Angeles, California, United States
# 4  2009-06-20  Beverly Hills, California, United States
#
#                                           host_about  host_response_time  \
# 0  Writer.\r\nLiterary Manager.\r\nPhotographer.\...      within an hour
# 1  Writer.\r\nLiterary Manager.\r\nPhotographer.\...      within an hour
# 2  A happy artist couple who travels often on tou...  within a few hours
# 3  My wife and I work in the entertainment indust...      within an hour
# 4  Hi there! Welcome! I'm a friendly and gracious...      within an hour
#
#   host_acceptance_rate host_is_superhost  \
# 0                  NaN                 t
# 1                  NaN                 t
# 2                  NaN                 t
# 3                  NaN                 t
# 4                  NaN                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/d17cf...
# 1  https://a0.muscache.com/im/pictures/user/d17cf...
# 2  https://a0.muscache.com/im/pictures/1734731e-3...
# 3  https://a0.muscache.com/im/users/22363/profile...
# 4  https://a0.muscache.com/im/pictures/user/bb777...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/d17cf...          Hollywood
# 1  https://a0.muscache.com/im/pictures/user/d17cf...          Hollywood
# 2  https://a0.muscache.com/im/pictures/1734731e-3...                NaN
# 3  https://a0.muscache.com/im/users/22363/profile...    Atwater Village
# 4  https://a0.muscache.com/im/pictures/user/bb777...    South Robertson
#
#                                   host_verifications host_has_profile_pic  \
# 0   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 1   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 2   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 3   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 4  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#   host_identity_verified                            street    neighbourhood  \
# 0                      t    Los Angeles, CA, United States              NaN
# 1                      t    Los Angeles, CA, United States              NaN
# 2                      t    Los Angeles, CA, United States  South Robertson
# 3                      t    Los Angeles, CA, United States  Atwater Village
# 4                      t  Beverly Hills, CA, United States    Beverly Hills
#
#   neighbourhood_cleansed           city state     zipcode       market  \
# 0              Hollywood    Los Angeles    CA       90046  Los Angeles
# 1              Hollywood    Los Angeles    CA       90046  Los Angeles
# 2               Mid-City    Los Angeles    CA  90034-2203  Los Angeles
# 3        Atwater Village    Los Angeles    CA       90039  Los Angeles
# 4          Beverly Hills  Beverly Hills    CA       90211  Los Angeles
#
#       smart_location country_code        country is_location_exact  \
# 0    Los Angeles, CA           US  United States                 t
# 1    Los Angeles, CA           US  United States                 t
# 2    Los Angeles, CA           US  United States                 t
# 3    Los Angeles, CA           US  United States                 t
# 4  Beverly Hills, CA           US  United States                 f
#
#   property_type        room_type  bed_type  \
# 0     Apartment     Private room  Real Bed
# 1     Apartment     Private room  Real Bed
# 2     Apartment  Entire home/apt  Real Bed
# 3    Guesthouse  Entire home/apt  Real Bed
# 4     Apartment     Private room  Real Bed
#
#                                            amenities calendar_updated  \
# 0  {Internet,Wifi,"Air conditioning","Wheelchair ...            today
# 1  {Internet,Wifi,"Air conditioning","Wheelchair ...       a week ago
# 2  {Internet,Wifi,Kitchen,Heating,"Family/kid fri...       a week ago
# 3  {TV,"Cable TV",Internet,Wifi,"Air conditioning...            today
# 4  {TV,Wifi,"Air conditioning",Kitchen,"Free stre...       5 days ago
#
#   has_availability calendar_last_scraped first_review last_review  \
# 0                t            2018-12-06   2014-06-09  2018-09-07
# 1                t            2018-12-06   2009-05-26  2018-05-31
# 2                t            2018-12-07   2009-06-01  2018-11-13
# 3                t            2018-12-07   2011-11-03  2018-11-21
# 4                t            2018-12-06   2009-06-24  2018-11-14
#
#   requires_license license             jurisdiction_names instant_bookable  \
# 0                f     NaN  {"City of Los Angeles"," CA"}                t
# 1                f     NaN  {"City of Los Angeles"," CA"}                t
# 2                f     NaN  {"City of Los Angeles"," CA"}                f
# 3                f     NaN  {"City of Los Angeles"," CA"}                t
# 4                f     NaN                            NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f                     flexible
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             t                                t
#
#                                                  uid
# 0  Chas.|Gold Memory Foam Bed & Breakfast in West...
# 1  Chas.|Off Sunset Wrap-Around Terr Runyon Canyo...
# 2  Leilani & Ova & Nouthak|15min from anywhere in...
# 3  Tom|Cozy Cottage/Home Away from Home/Close2Att...
# 4                    Sher|5-Star Beverly Hills Suite

# %%
for i in cat.columns:
    print(i,len(cat[i].unique()))
# Out:
# listing_url 11425
# last_scraped 2
# name 11348
# summary 10623
# space 9233
# description 11052
# experiences_offered 1
# neighborhood_overview 7861
# notes 6676
# transit 7393
# access 7992
# interaction 7469
# house_rules 8180
# medium_url 1
# picture_url 11307
# host_id 7085
# host_url 6411
# host_name 3206
# host_since 2489
# host_location 321
# host_about 4789
# host_response_time 5
# host_acceptance_rate 1
# host_is_superhost 2
# host_thumbnail_url 6407
# host_picture_url 6407
# host_neighbourhood 231
# host_verifications 269
# host_has_profile_pic 2
# host_identity_verified 2
# street 212
# neighbourhood 153
# neighbourhood_cleansed 240
# city 207
# state 4
# zipcode 361
# market 11
# smart_location 212
# country_code 1
# country 1
# is_location_exact 2
# property_type 37
# room_type 3
# bed_type 5
# amenities 11029
# calendar_updated 43
# has_availability 1
# calendar_last_scraped 2
# first_review 2115
# last_review 576
# requires_license 2
# license 255
# jurisdiction_names 8
# instant_bookable 2
# is_business_travel_ready 1
# cancellation_policy 6
# require_guest_profile_picture 2
# require_guest_phone_verification 2
# uid 11365

# %%
for i in cat.columns:
    print(i,sum(cat[i].isnull()))
# Out:
# listing_url 0
# last_scraped 0
# name 0
# summary 211
# space 1558
# description 59
# experiences_offered 0
# neighborhood_overview 2432
# notes 3918
# transit 2816
# access 2491
# interaction 2674
# house_rules 2198
# medium_url 11425
# picture_url 0
# host_id 0
# host_url 0
# host_name 0
# host_since 0
# host_location 21
# host_about 2682
# host_response_time 1649
# host_acceptance_rate 11425
# host_is_superhost 0
# host_thumbnail_url 0
# host_picture_url 0
# host_neighbourhood 1604
# host_verifications 0
# host_has_profile_pic 0
# host_identity_verified 0
# street 0
# neighbourhood 823
# neighbourhood_cleansed 0
# city 5
# state 1
# zipcode 131
# market 15
# smart_location 0
# country_code 0
# country 0
# is_location_exact 0
# property_type 0
# room_type 0
# bed_type 0
# amenities 0
# calendar_updated 0
# has_availability 0
# calendar_last_scraped 0
# first_review 643
# last_review 643
# requires_license 0
# license 11053
# jurisdiction_names 3460
# instant_bookable 0
# is_business_travel_ready 0
# cancellation_policy 0
# require_guest_profile_picture 0
# require_guest_phone_verification 0
# uid 0

# %%
cat.columns
# Out:
# Index(['listing_url', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        'transit', 'access', 'interaction', 'house_rules', 'medium_url',
#        'picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed', 'city', 'state', 'zipcode',
#        'market', 'smart_location', 'country_code', 'country',
#        'is_location_exact', 'property_type', 'room_type', 'bed_type',
#        'amenities', 'calendar_updated', 'has_availability',
#        'calendar_last_scraped', 'first_review', 'last_review',
#        'requires_license', 'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'uid'],
#       dtype='object')

# %%
# Columns that I'm keeping
cols = ['host_id', 'host_name', 'host_since',
        'host_response_time',
         'host_is_superhost',
       'host_neighbourhood',
       'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
        'neighbourhood_cleansed', 'city', 'state',
       'zipcode', 'market', 'smart_location', 
       'is_location_exact', 'property_type', 'room_type', 'bed_type',
       'amenities', 
        'instant_bookable',
       'cancellation_policy',
       'require_guest_profile_picture', 'require_guest_phone_verification']

# %%
cat[cols].head()
# Out:
#   host_id                host_name  host_since  host_response_time  \
# 0    3008                    Chas.  2008-09-16      within an hour
# 1    3008                    Chas.  2008-09-16      within an hour
# 2   18122  Leilani & Ova & Nouthak  2009-05-20  within a few hours
# 3   22363                      Tom  2009-06-19      within an hour
# 4   22460                     Sher  2009-06-20      within an hour
#
#   host_is_superhost host_neighbourhood  \
# 0                 t          Hollywood
# 1                 t          Hollywood
# 2                 t                NaN
# 3                 t    Atwater Village
# 4                 t    South Robertson
#
#                                   host_verifications host_has_profile_pic  \
# 0   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 1   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 2   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 3   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 4  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#   host_identity_verified neighbourhood_cleansed           city state  \
# 0                      t              Hollywood    Los Angeles    CA
# 1                      t              Hollywood    Los Angeles    CA
# 2                      t               Mid-City    Los Angeles    CA
# 3                      t        Atwater Village    Los Angeles    CA
# 4                      t          Beverly Hills  Beverly Hills    CA
#
#       zipcode       market     smart_location is_location_exact property_type  \
# 0       90046  Los Angeles    Los Angeles, CA                 t     Apartment
# 1       90046  Los Angeles    Los Angeles, CA                 t     Apartment
# 2  90034-2203  Los Angeles    Los Angeles, CA                 t     Apartment
# 3       90039  Los Angeles    Los Angeles, CA                 t    Guesthouse
# 4       90211  Los Angeles  Beverly Hills, CA                 f     Apartment
#
#          room_type  bed_type  \
# 0     Private room  Real Bed
# 1     Private room  Real Bed
# 2  Entire home/apt  Real Bed
# 3  Entire home/apt  Real Bed
# 4     Private room  Real Bed
#
#                                            amenities instant_bookable  \
# 0  {Internet,Wifi,"Air conditioning","Wheelchair ...                t
# 1  {Internet,Wifi,"Air conditioning","Wheelchair ...                t
# 2  {Internet,Wifi,Kitchen,Heating,"Family/kid fri...                f
# 3  {TV,"Cable TV",Internet,Wifi,"Air conditioning...                t
# 4  {TV,Wifi,"Air conditioning",Kitchen,"Free stre...                f
#
#            cancellation_policy require_guest_profile_picture  \
# 0  strict_14_with_grace_period                             f
# 1  strict_14_with_grace_period                             f
# 2  strict_14_with_grace_period                             f
# 3                     flexible                             f
# 4                     moderate                             t
#
#   require_guest_phone_verification
# 0                                f
# 1                                f
# 2                                f
# 3                                f
# 4                                t

# %%
# Looking at # of unique values for each categorial variables
for i in cat[cols].columns:
    print(i,len(cat[i].unique()))
# Out:
# host_id 7085
# host_name 3206
# host_since 2489
# host_response_time 5
# host_is_superhost 2
# host_neighbourhood 231
# host_verifications 269
# host_has_profile_pic 2
# host_identity_verified 2
# neighbourhood_cleansed 240
# city 207
# state 4
# zipcode 361
# market 11
# smart_location 212
# is_location_exact 2
# property_type 37
# room_type 3
# bed_type 5
# amenities 11029
# instant_bookable 2
# cancellation_policy 6
# require_guest_profile_picture 2
# require_guest_phone_verification 2

# %%
# Looking at Numerical data
num = population.select_dtypes(include = 'float').copy()

# %%
# Columns I'm keeping 
cols2 = ['id',
       'host_listings_count',
       'latitude', 'longitude', 'accommodates',
       'bathrooms', 'bedrooms', 'beds', 'price', 'weekly_price',
       'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
       'extra_people', 'minimum_nights', 'maximum_nights', 'availability_30',
       'availability_60', 'availability_90', 'availability_365',
       'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'calculated_host_listings_count',
       'reviews_per_month', 'isPlus']

# %%
num[cols2].head()
# Out:
#        id  host_listings_count   latitude   longitude  accommodates  \
# 0  2708.0                  2.0  34.097676 -118.346023           1.0
# 1  6931.0                  2.0  34.095213 -118.348011           1.0
# 2  7143.0                  1.0  34.034752 -118.377514           2.0
# 3  7992.0                  2.0  34.115426 -118.260902           4.0
# 4  8021.0                  1.0  34.064096 -118.380302           2.0
#
#    bathrooms  bedrooms  beds  price  weekly_price  monthly_price  \
# 0        1.5       1.0   1.0   79.0         399.0          949.0
# 1        1.5       1.0   1.0   99.0         269.0         1199.0
# 2        1.0       1.0   1.0   80.0         600.0         2000.0
# 3        1.0       1.0   2.0   69.0         450.0         1500.0
# 4        1.0       1.0   1.0  129.0         735.0         2400.0
#
#    security_deposit  cleaning_fee  guests_included  extra_people  \
# 0             299.0          85.0              1.0           0.0
# 1             350.0          89.0              1.0           0.0
# 2               0.0          25.0              2.0          25.0
# 3             100.0          45.0              2.0          10.0
# 4               0.0          45.0              2.0          45.0
#
#    minimum_nights  maximum_nights  availability_30  availability_60  \
# 0             6.0           366.0              0.0              0.0
# 1             6.0           375.0              5.0             14.0
# 2             2.0           365.0             19.0             49.0
# 3             1.0          1250.0              6.0             22.0
# 4             2.0            30.0             28.0             37.0
#
#    availability_90  availability_365  number_of_reviews  review_scores_rating  \
# 0              6.0             260.0               13.0                  97.0
# 1             44.0             319.0               12.0                  96.0
# 2             73.0             313.0              184.0                  94.0
# 3             44.0             271.0              135.0                  99.0
# 4             37.0             178.0              219.0                  96.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                        9.0                   10.0
# 2                    10.0                        9.0                   10.0
# 3                    10.0                       10.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                  9.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#    calculated_host_listings_count  reviews_per_month  isPlus
# 0                             2.0               0.24     NaN
# 1                             2.0               0.10     NaN
# 2                             1.0               1.59     NaN
# 3                             2.0               1.56     NaN
# 4                             1.0               1.90     NaN

# %%
# Looking at # of uniques in each cols
for i in cols2:
    print(i,len(num[i].unique()))
# Out:
# id 11425
# host_listings_count 41
# latitude 11425
# longitude 11425
# accommodates 16
# bathrooms 24
# bedrooms 12
# beds 21
# price 499
# weekly_price 452
# monthly_price 448
# security_deposit 132
# cleaning_fee 185
# guests_included 16
# extra_people 69
# minimum_nights 37
# maximum_nights 187
# availability_30 31
# availability_60 61
# availability_90 91
# availability_365 366
# number_of_reviews 400
# review_scores_rating 28
# review_scores_accuracy 8
# review_scores_cleanliness 9
# review_scores_checkin 8
# review_scores_communication 8
# review_scores_location 8
# review_scores_value 9
# calculated_host_listings_count 28
# reviews_per_month 973
# isPlus 2

# %%
# Final columns from Categorical and Numerical 
final_columns = cols + cols2

# %%
# Setting population_final_columns as table
population_final_columns = population[final_columns]

# %%
# Looking at NAN values
plt.figure(figsize=(20,12))
sns.heatmap(population_final_columns.isna())

# %%
plt.figure(figsize=(20,12))
sns.heatmap(population_final_columns[population_final_columns['isPlus']==0].isna())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-094111f1df20> in <module>
#       1 plt.figure(figsize=(20,12))
# ----> 2 sns.heatmap(population_final_columns[population_final_columns['isPlus']==0].isna())
#
# /anaconda3/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# /anaconda3/lib/python3.6/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     165         # Determine good default values for the colormapping
#     166         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 167                                     cmap, center, robust)
#     168
#     169         # Sort out the annotations
#
# /anaconda3/lib/python3.6/site-packages/seaborn/matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     204         calc_data = plot_data.data[~np.isnan(plot_data.data)]
#     205         if vmin is None:
# --> 206             vmin = np.percentile(calc_data, 2) if robust else calc_data.min()
#     207         if vmax is None:
#     208             vmax = np.percentile(calc_data, 98) if robust else calc_data.max()
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
just_plus = population_final_columns[population_final_columns['isPlus'] == 1]

# %%
sns.scatterplot(x='number_of_reviews',y='review_scores_rating',
                data=just_plus)

# %%
no_plus = population_final_columns[population_final_columns['isPlus'] != 1]

# %%
see = ['accommodates',
       'bathrooms', 'bedrooms', 'beds','number_of_reviews',
       'review_scores_accuracy','review_scores_cleanliness', 
       'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 
       'reviews_per_month','minimum_nights', 'maximum_nights', 
       'availability_30',
       'availability_60', 'availability_90', 'availability_365', 
       'price', 'weekly_price',
       'monthly_price', 'security_deposit', 'cleaning_fee', 
       'guests_included',
       'extra_people']
for i in see: 
    print(i)
    print("just_plus",sum(just_plus[i])/len(just_plus))
    print("no_plus",sum(no_plus[i].dropna())/len(no_plus))
    print("all",sum(population_final_columns[i].dropna())/len(population_final_columns),'\n')

# %%
g = sns.FacetGrid(no_plus                     
                  , row = 'host_is_superhost', col = 'isPlus')
g.map(plt.hist,"price")

# %%
g = plt.figure()
sns.pairplot(population_final_columns.fillna(0,axis=0),hue='isPlus',vars=see[5:11],)

# %%
sns.pairplot(population_final_columns.fillna("-1",axis=0),hue='isPlus',vars=see[18:23],)

# %%
sns.pairplot(population_final_columns.fillna("-1",axis=0),hue='isPlus',vars=see[:5],)

# %%
for i in population_final_columns.columns:
    print(i, str(sum(population_final_columns[i].isna())/len(population_final_columns)*100)[:5],'%')

# %%
population_final_columns[population_final_columns['isPlus']==1]['number_of_reviews'].describe()

# %%
population_final_columns[population_final_columns['isPlus']==0]['number_of_reviews'].describe()

# %%
plt.figure(figsize=(20,12))
sns.heatmap(population[cols2].corr())

# %%
population_final_columns.head()

# %%
# To CSV
 #population_final_columns.to_csv('Cleaner_Airbnb_Listingspt2.csv')
