# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import os
try:
	os.chdir(os.path.join(os.getcwd(), '../2019 Spring/SpringAccel'))
	print(os.getcwd())
except:
	pass
sns.set_style('whitegrid')
sns.set_palette("husl")
pd.options.display.max_columns = None
# Out:
# /Users/Work/Dropbox/2019 Spring/SpringAccel

# %%
df = pd.read_csv('Airbnb_Listings_with_Amenities.csv',index_col = 0)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    host_id                host_name  host_since  host_response_time  \
# 0     3008                    Chas.  2008-09-16      within an hour
# 1     3008                    Chas.  2008-09-16      within an hour
# 2    18122  Leilani & Ova & Nouthak  2009-05-20  within a few hours
# 3    22363                      Tom  2009-06-19      within an hour
# 4    22460                     Sher  2009-06-20      within an hour
#
#    host_is_superhost host_neighbourhood  \
# 0                  1          Hollywood
# 1                  1          Hollywood
# 2                  1                NaN
# 3                  1    Atwater Village
# 4                  1    South Robertson
#
#                                   host_verifications  host_has_profile_pic  \
# 0   ['email', 'phone', 'facebook', 'reviews', 'kba']                     1
# 1   ['email', 'phone', 'facebook', 'reviews', 'kba']                     1
# 2   ['email', 'phone', 'facebook', 'reviews', 'kba']                     1
# 3   ['email', 'phone', 'facebook', 'reviews', 'kba']                     1
# 4  ['email', 'phone', 'facebook', 'reviews', 'jum...                     1
#
#    host_identity_verified neighbourhood_cleansed           city state  \
# 0                       1              Hollywood    Los Angeles    CA
# 1                       1              Hollywood    Los Angeles    CA
# 2                       1               Mid-City    Los Angeles    CA
# 3                       1        Atwater Village    Los Angeles    CA
# 4                       1          Beverly Hills  Beverly Hills    CA
#
#       zipcode       market     smart_location  is_location_exact  \
# 0       90046  Los Angeles    Los Angeles, CA                  1
# 1       90046  Los Angeles    Los Angeles, CA                  1
# 2  90034-2203  Los Angeles    Los Angeles, CA                  1
# 3       90039  Los Angeles    Los Angeles, CA                  1
# 4       90211  Los Angeles  Beverly Hills, CA                  0
#
#   property_type        room_type  bed_type  \
# 0     Apartment     Private room  Real Bed
# 1     Apartment     Private room  Real Bed
# 2     Apartment  Entire home/apt  Real Bed
# 3    Guesthouse  Entire home/apt  Real Bed
# 4     Apartment     Private room  Real Bed
#
#                                            amenities  instant_bookable  \
# 0  ['Internet', 'Wifi', '"Air conditioning"', '"W...                 1
# 1  ['Internet', 'Wifi', '"Air conditioning"', '"W...                 1
# 2  ['Internet', 'Wifi', 'Kitchen', 'Heating', '"F...                 0
# 3  ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Air...                 1
# 4  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 0
#
#            cancellation_policy  require_guest_profile_picture  \
# 0  strict_14_with_grace_period                              0
# 1  strict_14_with_grace_period                              0
# 2  strict_14_with_grace_period                              0
# 3                     flexible                              0
# 4                     moderate                              1
#
#    require_guest_phone_verification      id  host_listings_count   latitude  \
# 0                                 0  2708.0                  2.0  34.097676
# 1                                 0  6931.0                  2.0  34.095213
# 2                                 0  7143.0                  1.0  34.034752
# 3                                 0  7992.0                  2.0  34.115426
# 4                                 1  8021.0                  1.0  34.064096
#
#     longitude  accommodates  bathrooms  bedrooms  beds  price  weekly_price  \
# 0 -118.346023           1.0        1.5       1.0   1.0   79.0         399.0
# 1 -118.348011           1.0        1.5       1.0   1.0   99.0         269.0
# 2 -118.377514           2.0        1.0       1.0   1.0   80.0         600.0
# 3 -118.260902           4.0        1.0       1.0   2.0   69.0         450.0
# 4 -118.380302           2.0        1.0       1.0   1.0  129.0         735.0
#
#    monthly_price  security_deposit  cleaning_fee  guests_included  \
# 0          949.0             299.0          85.0              1.0
# 1         1199.0             350.0          89.0              1.0
# 2         2000.0               0.0          25.0              2.0
# 3         1500.0             100.0          45.0              2.0
# 4         2400.0               0.0          45.0              2.0
#
#    extra_people  minimum_nights  maximum_nights  availability_30  \
# 0           0.0             6.0           366.0              0.0
# 1           0.0             6.0           375.0              5.0
# 2          25.0             2.0           365.0             19.0
# 3          10.0             1.0          1250.0              6.0
# 4          45.0             2.0            30.0             28.0
#
#    availability_60  availability_90  availability_365  number_of_reviews  \
# 0              0.0              6.0             260.0               13.0
# 1             14.0             44.0             319.0               12.0
# 2             49.0             73.0             313.0              184.0
# 3             22.0             44.0             271.0              135.0
# 4             37.0             37.0             178.0              219.0
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  97.0                    10.0                       10.0
# 1                  96.0                    10.0                        9.0
# 2                  94.0                    10.0                        9.0
# 3                  99.0                    10.0                       10.0
# 4                  96.0                    10.0                       10.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                   10.0                         10.0                     9.0
# 2                   10.0                         10.0                     9.0
# 3                   10.0                         10.0                    10.0
# 4                   10.0                         10.0                    10.0
#
#    review_scores_value  calculated_host_listings_count  reviews_per_month  \
# 0                 10.0                             2.0               0.24
# 1                  9.0                             2.0               0.10
# 2                  9.0                             1.0               1.59
# 3                 10.0                             2.0               1.56
# 4                 10.0                             1.0               1.90
#
#    isPlus  number_of_amenities  number_of_unique_amenities  \
# 0     0.0                   43                          43
# 1     0.0                   57                          53
# 2     0.0                   12                          12
# 3     0.0                   58                          55
# 4     0.0                   51                          48
#
#    number_of_host_verifications  listing_count_LA  Unnamed: 61   toilet  \
# 0                             5                 2        False    False
# 1                             5                 2        False     True
# 2                             5                 1        False    False
# 3                             5                 2        False    False
# 4                             7                 1        False    False
#
#    24-hour check-in  Accessible-height bed  Accessible-height toilet  \
# 0              True                  False                     False
# 1              True                   True                      True
# 2              True                  False                     False
# 3             False                   True                     False
# 4             False                   True                     False
#
#    Air conditioning  Air purifier  Alfresco bathtub  Amazon Echo  BBQ grill  \
# 0              True         False             False        False      False
# 1              True         False             False        False       True
# 2             False         False             False        False      False
# 3              True         False             False        False       True
# 4              True         False             False        False      False
#
#    Baby bath  Baby monitor  Babysitter recommendations  Bath towel  \
# 0      False         False                       False       False
# 1      False         False                       False       False
# 2      False         False                       False       False
# 3      False         False                       False       False
# 4      False         False                       False       False
#
#    Bathroom essentials  Bathtub with bath chair  Beach essentials  Beach view  \
# 0                False                    False             False       False
# 1                False                    False             False       False
# 2                False                    False             False       False
# 3                False                    False              True       False
# 4                False                    False              True       False
#
#    Bed linens  Bedroom comforts  Body soap  Breakfast table  Brick oven  \
# 0        True             False      False            False       False
# 1       False             False      False            False       False
# 2       False             False      False            False       False
# 3        True             False      False            False       False
# 4        True             False      False            False       False
#
#    Building staff  Buzzer/wireless intercom  Cable TV  \
# 0           False                      True     False
# 1           False                      True     False
# 2           False                     False     False
# 3           False                     False      True
# 4            True                     False     False
#
#    Carbon monoxide detector  Ceiling fan  Central air conditioning  \
# 0                      True        False                     False
# 1                      True        False                     False
# 2                     False        False                     False
# 3                      True        False                     False
# 4                      True        False                     False
#
#    Changing table  Children’s books and toys  Children’s dinnerware  \
# 0           False                      False                  False
# 1           False                      False                  False
# 2           False                      False                  False
# 3           False                      False                  False
# 4           False                      False                  False
#
#    Cleaning before checkout  Coffee maker  Convection oven  Cooking basics  \
# 0                     False          True            False            True
# 1                     False          True            False            True
# 2                     False         False            False           False
# 3                     False          True            False            True
# 4                     False          True            False            True
#
#    DVD player  Day bed  Disabled parking spot  Dishes and silverware  \
# 0       False    False                  False                   True
# 1       False    False                  False                   True
# 2       False    False                  False                  False
# 3       False    False                   True                   True
# 4       False    False                  False                   True
#
#    Double oven  EV charger  Electric profiling bed  En suite bathroom  \
# 0        False       False                   False              False
# 1        False        True                   False              False
# 2        False       False                   False              False
# 3        False       False                   False              False
# 4        False       False                   False              False
#
#    Espresso machine  Ethernet connection  Exercise equipment  \
# 0             False                False               False
# 1             False                False               False
# 2             False                False               False
# 3             False                 True               False
# 4             False                False               False
#
#    Extra pillows and blankets  Family/kid friendly  Fax machine  \
# 0                        True                False        False
# 1                       False                False        False
# 2                       False                 True        False
# 3                        True                 True        False
# 4                        True                False        False
#
#    Fire extinguisher  Fire pit  Fireplace guards  Firm mattress  \
# 0               True     False             False          False
# 1               True     False             False          False
# 2              False     False             False          False
# 3               True     False             False          False
# 4               True     False              True          False
#
#    First aid kit  Fixed grab bars for shower  Fixed grab bars for toilet  \
# 0           True                       False                       False
# 1           True                       False                       False
# 2          False                       False                       False
# 3           True                       False                       False
# 4           True                       False                       False
#
#    Flat path to front door  Formal dining area  Free parking on premises  \
# 0                    False               False                      True
# 1                    False               False                      True
# 2                    False               False                     False
# 3                     True               False                      True
# 4                    False               False                     False
#
#    Free street parking  Full kitchen  Game console  Garden or backyard  \
# 0                 True         False         False               False
# 1                False         False         False                True
# 2                False         False         False               False
# 3                 True         False         False                True
# 4                 True         False         False               False
#
#    Gas oven  Ground floor access  HBO GO  Hair dryer  Handheld shower head  \
# 0     False                False   False        True                 False
# 1     False                False   False        True                 False
# 2     False                False   False        True                 False
# 3     False                False   False        True                  True
# 4     False                False   False        True                 False
#
#    Heat lamps  Heated floors  Heated towel rack  High chair  \
# 0       False          False              False       False
# 1       False          False              False       False
# 2       False          False              False       False
# 3       False          False              False        True
# 4       False          False              False       False
#
#    High-resolution computer monitor  Host greets you  Hot tub  \
# 0                             False             True     True
# 1                             False            False     True
# 2                             False            False    False
# 3                             False            False    False
# 4                             False            False    False
#
#    Hot water kettle  Hot water  Indoor fireplace  Jetted tub  Lake access  \
# 0             False       True             False       False        False
# 1             False      False             False       False        False
# 2             False      False             False       False        False
# 3             False       True             False       False        False
# 4             False       True              True       False        False
#
#    Laptop friendly workspace  Lock on bedroom door  Long term stays allowed  \
# 0                       True                 False                    False
# 1                       True                  True                     True
# 2                       True                 False                    False
# 3                       True                  True                     True
# 4                       True                 False                     True
#
#    Luggage dropoff allowed  Memory foam mattress  Mini fridge  Misting system  \
# 0                    False                 False        False           False
# 1                     True                 False        False           False
# 2                    False                 False        False           False
# 3                     True                 False        False           False
# 4                     True                 False        False           False
#
#    Mobile hoist  Mountain view  Murphy bed  Other pet(s)  Outdoor kitchen  \
# 0         False          False       False         False            False
# 1         False          False       False         False            False
# 2         False          False       False         False            False
# 3         False          False       False         False            False
# 4         False          False       False         False            False
#
#    Outdoor parking  Outdoor seating  Outlet covers  Pack ’n Play/travel crib  \
# 0            False            False          False                     False
# 1            False            False          False                     False
# 2            False            False          False                     False
# 3            False            False          False                     False
# 4            False            False          False                     False
#
#    Paid parking off premises  Paid parking on premises  Patio or balcony  \
# 0                      False                     False              True
# 1                      False                     False              True
# 2                      False                     False             False
# 3                      False                     False             False
# 4                      False                     False              True
#
#    Pets allowed  Pets live on this property  Pillow-top mattress  Pocket wifi  \
# 0         False                       False                False        False
# 1         False                       False                False        False
# 2         False                       False                False        False
# 3         False                        True                False        False
# 4         False                       False                False        False
#
#    Pool cover  Pool toys  Pool with pool hoist  Private bathroom  \
# 0       False      False                 False             False
# 1       False      False                 False             False
# 2       False      False                 False             False
# 3       False      False                 False             False
# 4       False      False                 False             False
#
#    Private entrance  Private gym  Private hot tub  Private living room  \
# 0             False        False            False                False
# 1             False        False            False                False
# 2             False        False            False                False
# 3              True        False            False                False
# 4              True        False            False                False
#
#    Private pool  Projector and screen  Rain shower  Roll-in shower  \
# 0         False                 False        False           False
# 1         False                 False        False           False
# 2         False                 False        False           False
# 3         False                 False        False           False
# 4         False                 False        False           False
#
#    Room-darkening shades  Safety card  Self check-in  Shared gym  \
# 0                  False         True          False       False
# 1                  False         True          False       False
# 2                  False        False          False       False
# 3                  False        False           True       False
# 4                  False        False           True       False
#
#    Shared hot tub  Shared pool  Shower chair  Single level home  Smart TV  \
# 0           False        False         False               True     False
# 1           False        False         False               True     False
# 2           False        False         False              False     False
# 3           False        False         False               True     False
# 4           False        False         False              False     False
#
#    Smart lock  Smoke detector  Smoking allowed  Soaking tub  Sound system  \
# 0       False            True            False        False         False
# 1       False            True            False        False         False
# 2       False           False            False        False         False
# 3       False            True            False        False         False
# 4       False            True            False        False         False
#
#    Stair gates  Stand alone steam shower  Standing valet  Steam oven  \
# 0        False                     False           False       False
# 1        False                     False           False       False
# 2        False                     False           False       False
# 3        False                     False           False       False
# 4         True                     False           False       False
#
#    Step-free access  Suitable for events  Sun loungers  Table corner guards  \
# 0             False                False         False                False
# 1              True                False         False                False
# 2             False                False         False                False
# 3              True                False         False                False
# 4              True                False         False                False
#
#    Tennis court  Toilet paper  Touchless faucets  Walk-in shower  \
# 0         False         False              False           False
# 1         False         False              False           False
# 2         False         False              False           False
# 3         False         False              False           False
# 4         False         False              False           False
#
#    Warming drawer  Well-lit path to entrance  Wheelchair accessible  \
# 0           False                      False                   True
# 1           False                       True                   True
# 2           False                      False                  False
# 3           False                       True                  False
# 4           False                       True                  False
#
#    Wide clearance to bed  Wide clearance to shower  Wide doorway  \
# 0                  False                     False         False
# 1                   True                      True          True
# 2                  False                     False         False
# 3                   True                     False         False
# 4                  False                     False          True
#
#    Wide entryway  Wide hallway clearance  Window guards  Wine cooler  \
# 0          False                   False          False        False
# 1           True                    True          False        False
# 2          False                   False          False        False
# 3           True                   False          False        False
# 4           True                    True          False        False
#
#    translation missing: en.hosting_amenity_49  \
# 0                                        True
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                        True
#
#    translation missing: en.hosting_amenity_50  Balcony  Bathtub  Beachfront  \
# 0                                        True    False    False       False
# 1                                        True    False    False       False
# 2                                        True    False    False       False
# 3                                       False    False    False       False
# 4                                        True    False     True       False
#
#    Bidet  Breakfast  Cat(s)   Crib  Dishwasher  Dog(s)  Doorman  Dryer  \
# 0  False       True   False  False        True   False    False   True
# 1  False      False   False  False        True   False    False   True
# 2  False      False   False  False       False   False    False  False
# 3  False      False   False   True       False    True    False   True
# 4  False      False   False  False        True   False    False   True
#
#    Elevator  Essentials    Gym  Hammock  Hangers  Heating  Internet  Iron  \
# 0      True        True   True    False     True     True      True  True
# 1      True        True   True    False     True     True      True  True
# 2     False        True  False    False     True     True      True  True
# 3     False        True  False    False     True     True      True  True
# 4     False        True  False    False     True     True     False  True
#
#    Keypad  Kitchen  Kitchenette  Lockbox  Microwave  Mudroom  Netflix  Other  \
# 0   False     True        False    False       True    False    False  False
# 1   False     True        False    False       True    False    False  False
# 2   False     True        False    False      False    False    False  False
# 3   False     True        False     True       True    False    False  False
# 4   False     True        False    False       True    False    False  False
#
#     Oven   Pool  Printer  Refrigerator  Sauna  Shampoo  Ski-in/Ski-out  Stove  \
# 0   True  False    False          True  False     True           False   True
# 1   True  False    False          True  False     True           False   True
# 2  False  False    False         False  False    False           False  False
# 3   True  False    False          True  False     True           False   True
# 4   True  False    False          True  False     True           False   True
#
#       TV  Terrace  Washer  Waterfront  Wifi
# 0  False    False    True       False  True
# 1  False    False    True       False  True
# 2  False    False   False       False  True
# 3   True    False    True       False  True
# 4   True    False    True       False  True

# %%
print("Has of NA df: {}".format(any(df.isna())))
# Out:
# Has of NA df: True

# %%
df.describe()
# Out:
#             host_id  host_is_superhost  host_has_profile_pic  \
# count  1.142100e+04       11421.000000          11421.000000
# mean   5.669459e+07           0.997548              0.999562
# std    5.896919e+07           0.049455              0.020920
# min    5.900000e+01           0.000000              0.000000
# 25%    8.851608e+06           1.000000              1.000000
# 50%    3.213508e+07           1.000000              1.000000
# 75%    9.225142e+07           1.000000              1.000000
# max    2.152372e+08           1.000000              1.000000
#
#        host_identity_verified  is_location_exact  instant_bookable  \
# count            11421.000000       11421.000000      11421.000000
# mean                 0.538044           0.818755          0.439716
000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               10771.000000           10767.000000
# mean                    9.803918               9.949661
# std                     0.465512               0.294969
# min                     2.000000               2.000000
# 25%                    10.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                 10769.000000            10767.000000
# mean                      9.958956                9.823721
# std                       0.276940                0.437791
# min                       2.000000                2.000000
# 25%                      10.000000               10.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  calculated_host_listings_count  reviews_per_month  \
# count         10767.000000                    11421.000000       10778.000000
# mean              9.777654                        4.295946           2.761613
# std               0.489695                        7.353459           2.153703
# min               2.000000                        1.000000           0.010000
# 25%              10.000000                        1.000000           1.060000
# 50%              10.000000                        2.000000           2.290000
# 75%              10.000000                        4.000000           3.960000
# max              10.000000                       62.000000          17.840000
#
#              isPlus  number_of_amenities  number_of_unique_amenities  \
# count  11421.000000         11421.000000                11421.000000
# mean       0.021189            32.089747                   31.735575
# std        0.144020            12.344582                   11.847304
# min        0.000000             1.000000                    1.000000
# 25%        0.000000            23.000000                   23.000000
# 50%        0.000000            31.000000                   31.000000
# 75%        0.000000            40.000000                   39.000000
# max        1.000000           112.000000                  111.000000
#
#        number_of_host_verifications  listing_count_LA
# count                  11421.000000      11421.000000
# mean                       5.656247          4.286227
# std                        1.945501          7.347893
# min                        1.000000          1.000000
# 25%                        4.000000          1.000000
# 50%                        6.000000          2.000000
# 75%                        7.000000          4.000000
# max                       12.000000         62.000000

# %%
for i in df.columns: 
    if any(df[i].isna()):
        print("{} has {} NA".format(i,sum(df[i].isna())))
        print("Plus listings: {}".format(sum(df[df[i].isna()]['isPlus'].dropna())))
# Out:
# host_response_time has 1649 NA
# Plus listings: 29.0
# host_neighbourhood has 1604 NA
# Plus listings: 16.0
# city has 4 NA
# Plus listings: 0.0
# zipcode has 130 NA
# Plus listings: 1.0
# market has 15 NA
# Plus listings: 0.0
# bathrooms has 4 NA
# Plus listings: 0.0
# bedrooms has 4 NA
# Plus listings: 0.0
# beds has 2 NA
# Plus listings: 0.0
# review_scores_rating has 649 NA
# Plus listings: 0.0
# review_scores_accuracy has 650 NA
# Plus listings: 0.0
# review_scores_cleanliness has 650 NA
# Plus listings: 0.0
# review_scores_checkin has 654 NA
# Plus listings: 0.0
# review_scores_communication has 652 NA
# Plus listings: 0.0
# review_scores_location has 654 NA
# Plus listings: 0.0
# review_scores_value has 654 NA
# Plus listings: 0.0
# reviews_per_month has 643 NA
# Plus listings: 0.0

# %%
df[(df['zipcode'].isna()) & (df['isPlus']==1)][['latitude','longitude', 'zipcode']]
# Using longitude and latitude, we were able to fill in the zipcode 
df.set_value(630, 'zipcode', 90404)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
#          host_id                host_name  host_since  host_response_time  \
# 0           3008                    Chas.  2008-09-16      within an hour
# 1           3008                    Chas.  2008-09-16      within an hour
# 2          18122  Leilani & Ova & Nouthak  2009-05-20  within a few hours
# 3          22363                      Tom  2009-06-19      within an hour
# 4          22460                     Sher  2009-06-20      within an hour
# 5          23567                   Mayumi  2009-06-28                 NaN
# 6          26996                  Lillian  2009-07-22  within a few hours
# 7          28350                  Wendell  2009-07-29  within a few hours
# 8          30319                 Cristina  2009-08-07  within a few hours
# 9          40884        Suzan And Michael  2009-09-24      within an hour
# 10         30484                 Pascalou  2009-08-08      within an hour
# 11         55411               HankBubbie  2009-11-18      within an hour
# 12         60473                    Maddy  2009-12-06      within an hour
# 13         77857                  Barbara  2010-02-05      within an hour
# 14         55411               HankBubbie  2009-11-18      within an hour
# 15         55411               HankBubbie  2009-11-18      within an hour
# 16         94038                  Tatiana  2010-03-15      within an hour
# 17         55411               HankBubbie  2009-11-18      within an hour
# 18         98565                     Zara  2010-03-24      within an hour
# 19        105868                   Namhau  2010-04-09                 NaN
# 20         55411               HankBubbie  2009-11-18      within an hour
# 21        105868                   Namhau  2010-04-09                 NaN
# 22        140947                   Sheryl  2010-06-08  within a few hours
# 23        142776                  Spencer  2010-06-11      within an hour
# 24        144837                 Patricia  2010-06-15      within an hour
# 25        144855              Edwin Diego  2010-06-15      within an hour
# 26        160505                  Charles  2010-07-07                 NaN
# 27        191460                  Jeffrey  2010-08-04      within an hour
# 28        192939                     Lisa  2010-08-06      within an hour
# 29        201467                    Robin  2010-08-14                 NaN
# ...          ...                      ...         ...                 ...
# 11391   23048713                      Iry  2014-10-27      within an hour
# 11392  187656218                       Ji  2018-05-03      within an hour
# 11393   17054570                   Renato  2014-06-20      within an hour
# 11394  212556097                    Brian  2018-08-30      within an hour
# 11395   41822493                     John  2015-08-18      within an hour
# 11396  201371006                    Sandy  2018-07-10      within an hour
# 11397   44223189                    Nicky  2015-09-15      within an hour
# 11398   10767004                     Ofir  2013-12-22  within a few hours
# 11399  127250950            Lauren & Joel  2017-04-23  within a few hours
# 11400   38799051                     John  2015-07-17      within an hour
# 11401  182148017            George Dewann  2018-04-03      within an hour
# 11402    6445088                    David  2013-05-17      within an hour
# 11403   11051517                    Laura  2014-01-05      within an hour
# 11404    6605622                Mackenzie  2013-05-27      within an hour
# 11405   44223189                    Nicky  2015-09-15      within an hour
# 11406    4476176                   Stefan  2012-12-23      within an hour
# 11407   39653980         Sunshine & Sunny  2015-07-26                 NaN
# 11408   27829797                   Yvonne  2015-02-16                 NaN
# 11409   48005494                     Zeus  2015-11-02  within a few hours
# 11410   48005494                     Zeus  2015-11-02  within a few hours
# 11411   48005494                     Zeus  2015-11-02  within a few hours
# 11412   48005494                     Zeus  2015-11-02  within a few hours
# 11413  182148017            George Dewann  2018-04-03      within an hour
# 11414   23118355                   Ashton  2014-10-29  within a few hours
# 11415   34525952                    David  2015-05-29                 NaN
# 11416   39653980         Sunshine & Sunny  2015-07-26                 NaN
# 11417    7552589                 Michelle  2013-07-17      within an hour
# 11418   38799051                     John  2015-07-17      within an hour
# 11419   48005494                     Zeus  2015-11-02  within a few hours
# 11420   48005494                     Zeus  2015-11-02  within a few hours
#
#        host_is_superhost host_neighbourhood  \
# 0                      1          Hollywood
# 1                      1          Hollywood
# 2                      1                NaN
# 3                      1    Atwater Village
# 4                      1    South Robertson
# 5                      1           Downtown
# 6                      1             Venice
# 7                      1         Long Beach
# 8                      1             Venice
# 9                      1    Hollywood Hills
# 10                     1       Mid-Wilshire
# 11                     1    Hollywood Hills
# 12                     1             Venice
# 13                     1             Venice
# 14                     1    Hollywood Hills
# 15                     1    Hollywood Hills
# 16                     1      Highland Park
# 17                     1    Hollywood Hills
# 18                     1   Mount Washington
# 19                     1        Culver City
# 20                     1    Hollywood Hills
# 21                     1        Culver City
# 22                     1           Rosemead
# 23                     1        Culver City
# 24                     1             Malibu
# 25                     1         Eagle Rock
# 26                     1         West Adams
# 27                     1        Silver Lake
# 28                     1          Hollywood
# 29                     1        Silver Lake
# ...                  ...                ...
# 11391                  1    Hollywood Hills
# 11392                  1        Temple City
# 11393                  1      Beverly Hills
# 11394                  1           South LA
# 11395                  1                NaN
# 11396                  1    Manhattan Beach
# 11397                  1          Hollywood
# 11398                  1       Sherman Oaks
# 11399                  1                NaN
# 11400                  1         West Adams
# 11401                  1           Mid-City
# 11402                  1     Marina Del Rey
# 11403                  1          Mar Vista
# 11404                  1             Venice
# 11405                  1          Hollywood
# 11406                  1   West Los Angeles
# 11407                  1         Long Beach
# 11408                  1                NaN
# 11409                  1       Potrero Hill
# 11410                  1       Potrero Hill
# 11411                  1       Potrero Hill
# 11412                  1       Potrero Hill
# 11413                  1           Mid-City
# 11414                  1          Hollywood
# 11415                  1             Malibu
# 11416                  1         Long Beach
# 11417                  1       Santa Monica
# 11418                  1         West Adams
# 11419                  1       Potrero Hill
# 11420                  1       Potrero Hill
#
#                                       host_verifications  \
# 0       ['email', 'phone', 'facebook', 'reviews', 'kba']
# 1       ['email', 'phone', 'facebook', 'reviews', 'kba']
# 2       ['email', 'phone', 'facebook', 'reviews', 'kba']
# 3       ['email', 'phone', 'facebook', 'reviews', 'kba']
# 4      ['email', 'phone', 'facebook', 'reviews', 'jum...
# 5      ['email', 'phone', 'facebook', 'reviews', 'jum...
# 6                   ['email', 'phone', 'reviews', 'kba']
# 7       ['email', 'phone', 'facebook', 'reviews', 'kba']
# 8      ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 9                          ['email', 'phone', 'reviews']
# 10                  ['email', 'phone', 'reviews', 'kba']
# 11     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 12     ['email', 'phone', 'reviews', 'jumio', 'selfie...
# 13      ['email', 'phone', 'facebook', 'reviews', 'kba']
# 14     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 15     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 16      ['email', 'phone', 'facebook', 'reviews', 'kba']
# 17     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 18                         ['email', 'phone', 'reviews']
# 19                  ['email', 'phone', 'reviews', 'kba']
# 20     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 21                  ['email', 'phone', 'reviews', 'kba']
# 22     ['email', 'phone', 'facebook', 'reviews', 'off...
# 23     ['email', 'phone', 'facebook', 'reviews', 'kba...
# 24      ['email', 'phone', 'facebook', 'reviews', 'kba']
# 25     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 26                  ['email', 'phone', 'reviews', 'kba']
# 27     ['email', 'phone', 'reviews', 'jumio', 'offlin...
#
# 2              Apartment  Entire home/apt  Real Bed
# 3             Guesthouse  Entire home/apt  Real Bed
# 4              Apartment     Private room  Real Bed
# 5                   Loft  Entire home/apt  Real Bed
# 6             Guesthouse  Entire home/apt  Real Bed
# 7                   Loft     Private room  Real Bed
# 8              Apartment     Private room  Real Bed
# 9            Guest suite  Entire home/apt  Real Bed
# 10             Apartment  Entire home/apt  Real Bed
# 11             Apartment  Entire home/apt  Real Bed
# 12            Guesthouse  Entire home/apt  Real Bed
# 13            Guesthouse  Entire home/apt  Real Bed
# 14            Guesthouse  Entire home/apt  Real Bed
# 15            Guesthouse  Entire home/apt  Real Bed
# 16              Bungalow     Private room  Real Bed
# 17           Guest suite  Entire home/apt  Real Bed
# 18                 House  Entire home/apt  Real Bed
# 19     Bed and breakfast     Private room  Real Bed
# 20           Guest suite  Entire home/apt  Real Bed
# 21     Bed and breakfast     Private room  Real Bed
# 22                 House     Private room  Real Bed
# 23                 House  Entire home/apt  Real Bed
# 24            Guesthouse  Entire home/apt  Real Bed
# 25            Guesthouse  Entire home/apt  Real Bed
# 26           Guest suite  Entire home/apt  Real Bed
# 27                 House     Private room  Real Bed
# 28             Apartment  Entire home/apt  Real Bed
# 29              Bungalow  Entire home/apt  Real Bed
# ...                  ...              ...       ...
# 11391              House  Entire home/apt  Real Bed
# 11392              House  Entire home/apt  Real Bed
# 11393              House  Entire home/apt  Real Bed
# 11394             Hostel      Shared room  Real Bed
# 11395              House      Shared room  Real Bed
# 11396              House  Entire home/apt  Real Bed
# 11397          Apartment  Entire home/apt  Real Bed
# 11398              House  Entire home/apt  Real Bed
# 11399              House     Private room  Real Bed
# 11400        Guest suite     Private room  Real Bed
# 11401              House     Private room  Real Bed
# 11402        Condominium  Entire home/apt  Real Bed
# 11403          Apartment  Entire home/apt  Real Bed
# 11404        Guest suite  Entire home/apt  Real Bed
# 11405          Apartment  Entire home/apt  Real Bed
# 11406              House  Entire home/apt  Real Bed
# 11407              House     Private room  Real Bed
# 11408              House     Private room  Real Bed
# 11409          Townhouse  Entire home/apt  Real Bed
# 11410          Townhouse  Entire home/apt  Real Bed
# 11411          Townhouse  Entire home/apt  Real Bed
# 11412          Townhouse  Entire home/apt  Real Bed
# 11413              House     Private room  Real Bed
# 11414              House  Entire home/apt  Real Bed
# 11415              House  Entire home/apt  Real Bed
# 11416              House     Private room  Real Bed
# 11417          Apartment  Entire home/apt  Real Bed
# 11418              House     Private room  Real Bed
# 11419        Condominium  Entire home/apt  Real Bed
# 11420        Condominium  Entire home/apt  Real Bed
#
#                                                amenities  instant_bookable  \
# 0      ['Internet', 'Wifi', '"Air conditioning"', '"W...                 1
# 1      ['Internet', 'Wifi', '"Air conditioning"', '"W...                 1
# 2      ['Internet', 'Wifi', 'Kitchen', 'Heating', '"F...                 0
# 3      ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Air...                 1
# 4      ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 0
# 5      ['Internet', 'Wifi', '"Air conditioning"', 'Po...                 0
# 6      ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Pet...                 0
# 7      ['TV', '"Cable TV"', 'Wifi', '"Air conditionin...                 1
# 8      ['Internet', 'Wifi', 'Kitchen', '"Free street ...                 0
# 9      ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Air...                 0
# 10     ['TV', 'Internet', 'Wifi', 'Kitchen', '"Free p...                 0
# 11     ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Air...                 0
# 12     ['TV', '"Cable TV"', 'Internet', 'Wifi', 'Kitc...                 1
# 13     ['TV', '"Cable TV"', 'Internet', 'Wifi', 'Kitc...                 0
# 14     ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Air...                 0
# 15     ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Air...                 0
# 16     ['TV', 'Internet', 'Wifi', '"Air conditioning"...                 1
# 17     ['TV', '"Cable TV"', 'Internet', 'Wifi', 'Kitc...                 0
# 18     ['TV', '"Cable TV"', 'Wifi', '"Air conditionin...                 0
# 19     ['Internet', 'Wifi', '"Free parking on premise...                 0
# 20     ['TV', '"Cable TV"', 'Wifi', 'Kitchen', '"Pets...                 0
# 21     ['Internet', 'Wifi', 'Breakfast', 'Heating', '...                 0
# 22     ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 0
# 23     ['TV', '"Cable TV"', 'Internet', 'Wifi', 'Kitc...                 0
# 24     ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Air...                 0
# 25     ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Air...                 1
# 26     ['Wifi', '"Air conditioning"', 'Kitchen', '"Fr...                 1
# 27     ['TV', '"Cable TV"', 'Wifi', '"Air conditionin...                 1
# 28     ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Air...                 0
# 29     ['TV', '"Cable TV"', 'Internet', 'Wifi', '"Air...                 0
# ...                                                  ...               ...
# 11391  ['Wifi', '"Air conditioning"', '"Free parking ...                 1
# 11392  ['TV', 'Wifi', '"Air conditioning"', '"Free pa...                 1
# 11393  ['TV', 'Wifi', '"Air conditioning"', 'Pool', '...                 0
# 11394  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 0
# 11395  ['Wifi', '"Air conditioning"', 'Kitchen', 'Hea...                 1
# 11396  ['TV', 'Wifi', 'Kitchen', '"Free parking on pr...                 1
# 11397  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 1
# 11398  ['TV', '"Cable TV"', 'Wifi', '"Air conditionin...                 0
# 11399  ['TV', 'Wifi', 'Kitchen', '"Free parking on pr...                 0
# 11400  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 1
# 11401  ['TV', '"Cable TV"', 'Wifi', '"Air conditionin...                 1
# 11402  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 0
# 11403  ['Wifi', 'Kitchen', '"Free parking on premises...                 0
# 11404  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 1
# 11405  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 1
# 11406  ['TV', 'Wifi', '"Air conditioning"', 'Pool', '...                 0
# 11407  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 1
# 11408  ['Wifi', 'Kitchen', '"Free parking on premises...                 1
# 11409  ['TV', 'Internet', 'Wifi', 'Kitchen', 'Heating...                 0
# 11410  ['TV', 'Internet', 'Wifi', 'Kitchen', 'Heating...                 0
# 11411  ['TV', 'Internet', 'Wifi', 'Kitchen', 'Heating...                 0
# 11412  ['TV', 'Internet', 'Wifi', 'Kitchen', 'Heating...                 0
# 11413  ['TV', '"Cable TV"', 'Wifi', '"Air conditionin...                 1
# 11414  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 0
# 11415  ['TV', 'Wifi', '"Air conditioning"', 'Pool', '...                 0
# 11416  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 1
# 11417  ['TV', 'Wifi', '"Air conditioning"', 'Kitchen'...                 1
# 11418  ['TV', 'Wifi', '"Air conditioning"', '"Free pa...                 1
# 11419  ['TV', 'Internet', 'Wifi', 'Kitchen', 'Heating...                 0
# 11420  ['TV', 'Internet', 'Wifi', 'Kitchen', 'Heating...                 0
#
#                cancellation_policy  require_guest_profile_picture  \
# 0      strict_14_with_grace_period                              0
# 1      strict_14_with_grace_period                              0
# 2      strict_14_with_grace_period                              0
# 3                         flexible                              0
# 4                         moderate                              1
# 5                         moderate                              0
# 6      strict_14_with_grace_period                              1
# 7                         moderate                              0
# 8      strict_14_with_grace_period                              0
# 9      strict_14_with_grace_period                              0
# 10     strict_14_with_grace_period                              0
# 11     strict_14_with_grace_period                              1
# 12     strict_14_with_grace_period                              0
# 13     strict_14_with_grace_period                              0
# 14     strict_14_with_grace_period                              1
# 15     strict_14_with_grace_period                              1
# 16                        moderate                              0
# 17     strict_14_with_grace_period                              1
# 18                        moderate                              0
# 19     strict_14_with_grace_period                              0
# 20     strict_14_with_grace_period                              1
# 21     strict_14_with_grace_period                              0
# 22                        moderate                              0
# 23     strict_14_with_grace_period                              0
# 24     strict_14_with_grace_period                              1
# 25                        moderate                              0
# 26                        flexible                              0
# 27                        moderate                              0
# 28     strict_14_with_grace_period                              0
# 29                        moderate                              0
# ...                            ...                            ...
# 11391                     flexible                              0
# 11392                     flexible                              0
# 11393                     flexible                              0
# 11394                     moderate                              0
# 11395                     flexible                              0
# 11396  strict_14_with_grace_period                              0
# 11397                     flexible                              0
# 11398                     flexible                              0
# 11399  strict_14_with_grace_period                              0
# 11400                     flexible                              0
# 11401                     flexible                              0
# 11402                     moderate                              0
# 11403                     moderate                              0
# 11404  strict_14_with_grace_period                              0
# 11405                     flexible                              0
# 11406                     flexible                              0
# 11407                     moderate                              0
# 11408  strict_14_with_grace_period                              0
# 11409                       strict                              0
# 11410                       strict                              0
# 11411                       strict                              0
# 11412                       strict                              0
# 11413                     flexible                              0
# 11414  strict_14_with_grace_period                              0
# 11415                     flexible                              0
# 11416  strict_14_with_grace_period                              0
# 11417  strict_14_with_grace_period                              0
# 11411  33.995391 -118.467979           2.0        1.0       0.0   0.0   160.0
# 11412  33.995036 -118.468028           4.0        1.0       2.0   2.0   235.0
# 11413  34.038066 -118.344899           3.0        2.0       1.0   2.0    59.0
# 11414  34.139932 -118.390001           4.0        2.0       1.0   2.0   219.0
# 11415  34.040014 -118.619461           6.0        3.5       3.0   4.0   540.0
# 11416  33.775487 -118.171798           1.0        2.0       1.0   1.0    60.0
# 11417  34.015964 -118.457732           2.0        1.0       1.0   1.0   130.0
# 11418  34.030866 -118.310741           3.0        1.5       1.0   2.0    40.0
# 11419  34.047097 -118.263425           2.0        1.0       0.0   0.0   120.0
# 11420  34.046863 -118.264962           2.0        1.0       1.0   1.0   133.0
#
#        weekly_price  monthly_price  security_deposit  cleaning_fee  \
# 0             399.0          949.0             299.0          85.0
# 1             269.0         1199.0             350.0          89.0
# 2             600.0         2000.0               0.0          25.0
# 3             450.0         1500.0             100.0          45.0
# 4             735.0         2400.0               0.0          45.0
# 5               0.0            0.0             100.0          40.0
# 6               0.0            0.0               0.0          52.0
# 7               0.0            0.0               0.0          35.0
# 8               0.0            0.0               0.0          80.0
# 9            1100.0         3100.0             200.0          75.0
# 10            500.0         1950.0             300.0          40.0
# 11              0.0            0.0            2500.0         175.0
# 12              0.0            0.0             250.0           0.0
# 13            700.0            0.0             300.0           0.0
# 14           1750.0         4450.0            1000.0         125.0
# 15           1550.0         3550.0             750.0         100.0
# 16            450.0         1650.0             200.0          50.0
# 17           1650.0         3250.0            1000.0         100.0
# 18           1300.0         5600.0               0.0         100.0
# 19              0.0            0.0             100.0          25.0
# ...
# 11412    False   True     False        True  False    False     True     True
# 11413    False   True     False        True  False    False     True     True
# 11414    False   True     False        True  False    False     True     True
# 11415    False   True     False        True  False    False     True     True
# 11416    False   True     False        True  False    False     True     True
# 11417    False   True     False        True  False    False     True     True
# 11418    False  False     False        True  False    False     True     True
# 11419    False   True     False        True  False    False     True     True
# 11420    False   True     False        True  False    False     True     True
#
#        Internet   Iron  Keypad  Kitchen  Kitchenette  Lockbox  Microwave  \
# 0          True   True   False     True        False    False       True
# 1          True   True   False     True        False    False       True
# 2          True   True   False     True        False    False      False
# 3          True   True   False     True        False     True       True
# 4         False   True   False     True        False    False       True
# 5          True   True   False     True        False    False      False
# 6          True   True   False    False        False    False       True
# 7         False   True   False     True        False     True       True
# 8          True  False   False     True        False    False      False
# 9          True   True   False     True        False    False      False
# 10         True   True   False     True        False    False      False
# 11         True   True   False     True        False    False       True
# 12         True   True   False     True         True     True       True
# 13         True   True   False     True        False    False      False
# 14         True   True   False     True        False    False      False
# 15         True   True    True     True        False    False       True
# 16         True   True   False     True        False     True       True
# 17         True   True   False     True        False    False      False
# 18        False   True   False     True        False    False       True
# 19         True  False   False    False        False    False      False
# 20        False   True   False     True        False    False       True
# 21         True  False   False    False        False    False      False
# 22        False   True   False     True        False    False       True
# 23         True   True    True     True        False    False       True
# 24         True   True   False     True        False    False       True
# 25         True   True   False     True        False    False      False
# 26        False   True   False     True        False    False       True
# 27        False   True   False     True        False     True       True
# 28         True   True   False     True        False     True       True
# 29         True   True   False     True        False     True       True
# ...         ...    ...     ...      ...          ...      ...        ...
# 11391     False  False   False    False        False    False      False
# 11392     False  False   False    False        False     True      False
# 11393     False   True   False     True        False    False       True
# 11394     False   True   False     True        False    False       True
# 11395     False  False   False     True        False    False      False
# 11396     False   True   False     True        False    False      False
# 11397     False   True    True     True        False    False       True
# 11398     False   True   False     True        False    False       True
# 11399     False  False   False     True        False    False      False
# 11400     False   True   False     True        False     True      False
# 11401     False   True   False     True        False    False       True
# 11402     False   True    True     True        False    False      False
# 11403     False  False   False     True        False     True      False
# 11404     False   True   False     True        False    False       True
# 11405     False   True   False     True        False    False      False
# 11406     False   True   False     True        False    False       True
# 11407     False   True   False     True        False    False      False
# 11408     False   True   False     True        False    False      False
# 11409      True   True   False     True        False    False      False
# 11410      True   True   False     True        False    False      False
# 11411      True   True   False     True        False    False      False
# 11412      True   True   False     True        False    False      False
# 11413     False   True   False     True        False    False       True
# 11414     False   True   False     True        False    False      False
# 11415     False  False   False     True        False    False      False
# 11416     False   True   False     True        False    False      False
# 11417     False   True   False     True        False     True      False
# 11418     False   True   False    False        False    False      False
# 11419      True   True   False     True        False    False      False
# 11420      True   True   False     True        False    False      False
#
#        Mudroom  Netflix  Other   Oven   Pool  Printer  Refrigerator  Sauna  \
# 0        False    False  False   True  False    False          True  False
# 1        False    False  False   True  False    False          True  False
# 2        False    False  False  False  False    False         False  False
# 3        False    False  False   True  False    False          True  False
# 4        False    False  False   True  False    False          True  False
# 5        False    False  False  False   True    False         False  False
# 6        False    False   True  False  False    False         False  False
# 7        False    False  False   True  False    False          True  False
# 8        False    False  False  False  False    False         False  False
# 9        False    False  False  False  False    False         False  False
# 10       False    False  False  False  False    False         False  False
# 11       False    False  False  False  False    False          True  False
# 12       False    False  False  False  False    False          True  False
# 13       False    False   True  False  False    False         False  False
# 14       False    False  False  False  False    False         False  False
# 15       False    False  False  False  False    False          True  False
# 16       False    False  False   True  False    False          True  False
# 17       False    False  False  False  False    False         False  False
# 18       False    False  False   True  False    False          True  False
# 19       False    False  False  False  False    False         False  False
# 20       False    False  False  False  False    False          True  False
# 21       False    False  False  False  False    False         False  False
# 22       False    False   True   True  False    False          True  False
# 23       False    False  False   True  False    False          True  False
# 24       False    False  False   True  False    False          True  False
# 25       False    False   True  False  False    False         False  False
# 26       False    False  False  False  False    False          True  False
# 27       False    False  False   True  False    False          True  False
# 28       False    False  False   True  False    False          True  False
# 29       False    False  False   True  False    False          True  False
# ...        ...      ...    ...    ...    ...      ...           ...    ...
# 11391    False    False  False  False  False    False         False  False
# 11392    False    False  False  False  False    False         False  False
# 11393    False    False  False   True   True    False          True  False
# 11394    False    False  False  False  False    False          True  False
# 11395    False    False  False  False  False    False         False  False
# 11396    False    False  False  False  False    False         False  False
# 11397    False    False  False   True  False    False          True  False
# 11398    False    False  False   True  False    False          True  False
# 11399    False    False  False  False  False    False         False  False
# 11400    False    False  False  False  False    False         False  False
# 11401    False    False   True   True  False    False          True  False
# 11402    False    False  False  False  False    False         False  False
# 11403    False    False  False  False  False    False         False  False
# 11404    False    False  False   True  False    False          True  False
# 11405    False    False  False  False  False    False         False  False
# 11406    False    False  False   True   True    False          True  False
# 11407    False    False  False  False  False    False         False  False
# 11408    False    False  False  False  False    False         False  False
# 11409    False    False  False  False  False    False         False  False
# 11410    False    False  False  False  False    False         False  False
# 11411    False    False  False  False  False    False         False  False
# 11412    False    False  False  False  False    False         False  False
# 11413    False    False  False   True  False    False          True  False
# 11414    False    False  False  False  False    False         False  False
# 11415    False    False  False  False   True    False         False  False
# 11416    False    False  False  False  False    False         False  False
# 11417    False    False  False  False  False    False         False  False
# 11418    False    False  False  False  False    False         False  False
# 11419    False    False  False  False  False    False         False  False
# 11420    False    False  False  False  False    False         False  False
#
#        Shampoo  Ski-in/Ski-out  Stove     TV  Terrace  Washer  Waterfront  \
# 0         True           False   True  False    False    True       False
# 1         True           False   True  False    False    True       False
# 2        False           False  False  False    False   False       False
# 3         True           False   True   True    False    True       False
# 4         True           False   True   True    False    True       False
# 5         True           False  False  False    False    True       False
# 6        False           False  False   True    False   False       False
# 7         True           False   True   True    False    True       False
# 8         True           False  False  False    False   False       False
# 9         True           False  False   True    False    True       False
# 10        True           False  False   True    False    True       False
# 11        True           False   True   True    False    True       False
# 12        True           False  False   True    False   False       False
# 13        True           False  False   True    False   False       False
# 14        True           False  False   True    False    True       False
# 15        True           False  False   True    False    True       False
# 16        True           False   True   True    False    True       False
# 17        True           False  False   True    False    True       False
# 18        True           False   True   True    False    True       False
# 19       False           False  False  False    False   False       False
# 20        True           False  False   True    False    True       False
# 21       False           False  False  False    False   False       False
# 22        True           False   True   True    False    True       False
# 23        True           False   True   True     True    True       False
# 24        True           False   True   True    False   False       False
# 25        True           False  False   True    False   False       False
# 26        True           False  False  False    False   False       False
# 27        True           False   True   True    False    True       False
# 28        True           False   True   True    False    True       False
# 29        True           False   True   True    False    True       False
# ...        ...             ...    ...    ...      ...     ...         ...
# 11391     True           False  False  False    False   False       False
# 11392     True           False  False   True    False   False       False
# 11393     True           False   True   True    False    True       False
# 11394     True           False   True   True    False    True       False
# 11395    False           False  False  False    False    True       False
# 11396     True           False  False   True    False    True       False
# 11397     True           False   True   True    False    True       False
# 11398    False           False   True   True    False   False       False
# 11399     True           False  False   True    False    True       False
# 11400     True           False  False   True    False    True       False
# 11401     True           False   True   True    False    True       False
# 11402     True           False  False   True    False    True       False
# 11403     True           False  False  False    False    True       False
# 11404     True           False   True   True    False    True       False
# 11405     True           False  False   True    False   False       False
# 11406     True           False   True   True    False    True       False
# 11407     True           False  False   True    False    True       False
# 11408    False           False  False  False    False   False       False
# 11409     True           False  False   True    False    True       False
# 11410     True           False  False   True    False    True       False
# 11411     True           False  False   True    False    True       False
# 11412     True           False  False   True    False    True       False
# 11413     True           False   True   True    False    True       False
# 11414     True           False  False   True    False    True       False
# 11415    False           False  False   True    False    True       False
# 11416     True           False  False   True    False    True       False
# 11417     True           False  False   True    False    True       False
# 11418     True           False  False   True    False   False       False
# 11419     True           False  False   True    False    True       False
# 11420     True           False  False   True    False    True       False
#
#        Wifi
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# ...     ...
# 11391  True
# 11392  True
# 11393  True
# 11394  True
# 11395  True
# 11396  True
# 11397  True
# 11398  True
# 11399  True
# 11400  True
# 11401  True
# 11402  True
# 11403  True
# 11404  True
# 11405  True
# 11406  True
# 11407  True
# 11408  True
# 11409  True
# 11410  True
# 11411  True
# 11412  True
# 11413  True
# 11414  True
# 11415  True
# 11416  True
# 11417  True
# 11418  True
# 11419  True
# 11420  True
#
# [11421 rows x 254 columns]

# %%
df.drop('host_neighbourhood',axis=1,inplace=True)

# %%
df.drop('amenities',axis=1,inplace=True)

# %%
df['host_response_time'].value_counts()
# Out:
# within an hour        8195
# within a few hours    1286
# within a day           281
# a few days or more      10
# Name: host_response_time, dtype: int64

# %%
newvar = list(df[(df['host_response_time'].isna())].reset_index()['index'])
for i in newvar:
    df.set_value(i, 'host_response_time','Unavaliable')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
for i in df.columns: 
    if any(df[i].isna()):
        print("{} has {} NA".format(i,sum(df[i].isna())))
        print("Plus listings: {}".format(sum(df[df[i].isna()]['isPlus'].dropna())))
# Out:
# city has 4 NA
# Plus listings: 0.0
# zipcode has 129 NA
# Plus listings: 0.0
# market has 15 NA
# Plus listings: 0.0
# bathrooms has 4 NA
# Plus listings: 0.0
# bedrooms has 4 NA
# Plus listings: 0.0
# beds has 2 NA
# Plus listings: 0.0
# review_scores_rating has 649 NA
# Plus listings: 0.0
# review_scores_accuracy has 650 NA
# Plus listings: 0.0
# review_scores_cleanliness has 650 NA
# Plus listings: 0.0
# review_scores_checkin has 654 NA
# Plus listings: 0.0
# review_scores_communication has 652 NA
# Plus listings: 0.0
# review_scores_location has 654 NA
# Plus listings: 0.0
# review_scores_value has 654 NA
# Plus listings: 0.0
# reviews_per_month has 643 NA
# Plus listings: 0.0

# %%
# Dropping all rows with NA  cause doesn't affect Plus listings
df.dropna(axis=0,inplace = True)
for i in df.columns: 
    if any(df[i].isna()):
        print("{} has {} NA".format(i,sum(df[i].isna())))
        print("Plus listings: {}".format(sum(df[df[i].isna()]['isPlus'].dropna())))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10664 entries, 0 to 11388
# Columns: 252 entries, host_id to Wifi
# dtypes: bool(194), float64(32), int64(12), object(14)
# memory usage: 6.8+ MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from sklearn.metrics import classification_report,confusion_matrix

# %%
for i in df.columns: 
    print(i)
# Out:
# host_id
# host_name
# host_since
# host_response_time
# host_is_superhost
# host_verifications
# host_has_profile_pic
# host_identity_verified
# neighbourhood_cleansed
# city
# state
# zipcode
# market
# smart_location
# is_location_exact
# property_type
# room_type
# bed_type
# instant_bookable
# cancellation_policy
# require_guest_profile_picture
# require_guest_phone_verification
# id
# host_listings_count
# latitude
# longitude
# accommodates
# bathrooms
# bedrooms
# beds
# price
# weekly_price
# monthly_price
# security_deposit
# cleaning_fee
# guests_included
# extra_people
# minimum_nights
# maximum_nights
# availability_30
# availability_60
# availability_90
# availability_365
# number_of_reviews
# review_scores_rating
# review_scores_accuracy
# review_scores_cleanliness
# review_scores_checkin
# review_scores_communication
# review_scores_location
# review_scores_value
# calculated_host_listings_count
# reviews_per_month
# isPlus
# number_of_amenities
# number_of_unique_amenities
# number_of_host_verifications
# listing_count_LA
# Unnamed: 61
#  toilet
# 24-hour check-in
# Accessible-height bed
# Accessible-height toilet
# Air conditioning
# Air purifier
# Alfresco bathtub
# Amazon Echo
# BBQ grill
# Baby bath
# Baby monitor
# Babysitter recommendations
# Bath towel
# Bathroom essentials
# Bathtub with bath chair
# Beach essentials
# Beach view
# Bed linens
# Bedroom comforts
# Body soap
# Breakfast table
# Brick oven
# Building staff
# Buzzer/wireless intercom
# Cable TV
# Carbon monoxide detector
# Ceiling fan
# Central air conditioning
# Changing table
# Children’s books and toys
# Children’s dinnerware
# Cleaning before checkout
# Coffee maker
# Convection oven
# Cooking basics
# DVD player
# Day bed
# Disabled parking spot
# Dishes and silverware
# Double oven
# EV charger
# Electric profiling bed
# En suite bathroom
# Espresso machine
# Ethernet connection
# Exercise equipment
# Extra pillows and blankets
# Family/kid friendly
# Fax machine
# Fire extinguisher
# Fire pit
# Fireplace guards
# Firm mattress
# First aid kit
# Fixed grab bars for shower
# Fixed grab bars for toilet
# Flat path to front door
# Formal dining area
# Free parking on premises
# Free street parking
# Full kitchen
# Game console
# Garden or backyard
# Gas oven
# Ground floor access
# HBO GO
# Hair dryer
# Handheld shower head
# Heat lamps
# Heated floors
# Heated towel rack
# High chair
# High-resolution computer monitor
# Host greets you
# Hot tub
# Hot water kettle
# Hot water
# Indoor fireplace
# Jetted tub
# Lake access
# Laptop friendly workspace
# Lock on bedroom door
# Long term stays allowed
# Luggage dropoff allowed
# Memory foam mattress
# Mini fridge
# Misting system
# Mobile hoist
# Mountain view
# Murphy bed
# Other pet(s)
# Outdoor kitchen
# Outdoor parking
# Outdoor seating
# Outlet covers
# Pack ’n Play/travel crib
# Paid parking off premises
# Paid parking on premises
# Patio or balcony
# Pets allowed
# Pets live on this property
# Pillow-top mattress
# Pocket wifi
# Pool cover
# Pool toys
# Pool with pool hoist
# Private bathroom
# Private entrance
# Private gym
# Private hot tub
# Private living room
# Private pool
# Projector and screen
# Rain shower
# Roll-in shower
# Room-darkening shades
# Safety card
# Self check-in
# Shared gym
# Shared hot tub
# Shared pool
# Shower chair
# Single level home
# Smart TV
# Smart lock
# Smoke detector
# Smoking allowed
# Soaking tub
# Sound system
# Stair gates
# Stand alone steam shower
# Standing valet
# Steam oven
# Step-free access
# Suitable for events
# Sun loungers
# Table corner guards
# Tennis court
# Toilet paper
# Touchless faucets
# Walk-in shower
# Warming drawer
# Well-lit path to entrance
# Wheelchair accessible
# Wide clearance to bed
# Wide clearance to shower
# Wide doorway
# Wide entryway
# Wide hallway clearance
# Window guards
# Wine cooler
# translation missing: en.hosting_amenity_49
# translation missing: en.hosting_amenity_50
# Balcony
# Bathtub
# Beachfront
# Bidet
# Breakfast
# Cat(s)
# Crib
# Dishwasher
# Dog(s)
# Doorman
# Dryer
# Elevator
# Essentials
# Gym
# Hammock
# Hangers
# Heating
# Internet
# Iron
# Keypad
# Kitchen
# Kitchenette
# Lockbox
# Microwave
# Mudroom
# Netflix
# Other
# Oven
# Pool
# Printer
# Refrigerator
# Sauna
# Shampoo
# Ski-in/Ski-out
# Stove
# TV
# Terrace
# Washer
# Waterfront
# Wifi

# %%
# Making Judgment call: Removing some columns might add back later

df_model = df.drop(['host_id','host_name','host_since','host_verifications','neighbourhood_cleansed','city','state','zipcode','market','smart_location','id','Unnamed: 61'], axis=1)

# %%
items=list(df_model.select_dtypes('object').columns)
for cols in items:
    add = pd.get_dummies(df_model[cols],drop_first=True)
    df_model=pd.concat([df_model,add], axis=1)

df_model.drop(items,axis=1, inplace= True)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_model.drop('isPlus',axis= 1),df_model['isPlus'],train_size = 0.8181818182,stratify=df_model['isPlus'])
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
# Best Model So far
"""
The “balanced” mode uses the values of y to automatically adjust weights inversely proportional to class frequencies in the input data as 
n_samples / (n_classes * np.bincount(y)).

"""
logmodel = LogisticRegression(class_weight='balanced' ,max_iter=50,n_jobs=-1)
logmodel.fit(X_train,y_train)
predictions_log = logmodel.predict(X_test)
print(classification_report(y_test, predictions_log))
print(confusion_matrix(y_test, predictions_log))

"""
Problem: Since we don't have the full list, it is possible that FP 
can be much more since we only have 240 out of the 900+ plus listings. 
Is this a big problem?  
"""
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:1300: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 4.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.97      0.99      1895
#          1.0       0.47      0.98      0.63        44
#
#    micro avg       0.97      0.97      0.97      1939
#    macro avg       0.73      0.98      0.81      1939
# weighted avg       0.99      0.97      0.98      1939
#
# [[1846   49]
#  [   1   43]]
# "\nProblem: Since we don't have the full list, it is possible that FP \ncan be much more since we only have 240 out of the 900+ plus listings. \nIs this a big problem?  \n"

# %%
rfc = RandomForestClassifier(n_estimators=150,n_jobs=-1)
rfc.fit(X_train,y_train)
predictions_rfc = rfc.predict(X_test)
print(classification_report(y_test, predictions_rfc))
print(confusion_matrix(y_test, predictions_rfc))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      1895
#          1.0       0.94      0.36      0.52        44
#
#    micro avg       0.99      0.99      0.99      1939
#    macro avg       0.96      0.68      0.76      1939
# weighted avg       0.98      0.99      0.98      1939
#
# [[1894    1]
#  [  28   16]]

# %%
model = SVC()
model.fit(X_train,y_train)
predictions_svc = model.predict(X_test)
print(classification_report(y_test, predictions_svc))
print(confusion_matrix(y_test, predictions_svc))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      1895
#          1.0       0.00      0.00      0.00        44
#
#    micro avg       0.98      0.98      0.98      1939
#    macro avg       0.49      0.50      0.49      1939
# weighted avg       0.96      0.98      0.97      1939
#
# [[1895    0]
#  [  44    0]]

# %%
print("These are the scores\nLogistic: {}\nRandomForest: {}\nSVC: {}".format(
    logmodel.score(X_test,y_test),rfc.score(X_test,y_test),model.score(X_test,y_test)))
# Out:
# These are the scores
# Logistic: 0.9742135121196493
# RandomForest: 0.9850438370293966
# SVC: 0.9773078906652913

# %%
df_copy = df_model
important_cols = ['Bathroom essentials', 'Breakfast table', 'Ceiling fan', 'En suite bathroom', 'Espresso machine', 'Full kitchen', 'Gas oven', 'HBO GO', 'Hot water kettle', 'Memory foam mattress', 'Mini fridge', 'Outdoor seating', 'Pillow-top mattress', 'Smart TV', 'Sun loungers', 'Walk-in shower', 'Netflix']
for i in df_model.columns:
    try: 
        if df_copy[i].dtype == 'bool' and i not in important_cols:
            df_copy.drop(i,axis=1,inplace = True)
    except:
        pass

# %%
X_trainx, X_testx, y_trainx, y_testx = train_test_split(df_copy.drop('isPlus',axis= 1),df_copy['isPlus'],train_size = 0.8181818182,stratify=df_copy['isPlus'])
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
logmodelx = LogisticRegression(class_weight='balanced')
logmodelx.fit(X_trainx,y_trainx)
predictions_log = logmodelx.predict(X_testx)
print(classification_report(y_testx, predictions_log))
print(confusion_matrix(y_testx, predictions_log))
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.97      0.98      1895
#          1.0       0.40      0.95      0.57        44
#
#    micro avg       0.97      0.97      0.97      1939
#    macro avg       0.70      0.96      0.78      1939
# weighted avg       0.99      0.97      0.97      1939
#
# [[1833   62]
#  [   2   42]]

# %%
rfcx = RandomForestClassifier(n_estimators=150,n_jobs=-1)
rfcx.fit(X_trainx,y_trainx)
predictions_rfc = rfcx.predict(X_testx)
print(classification_report(y_testx, predictions_rfc))
print(confusion_matrix(y_testx, predictions_rfc))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      1895
#          1.0       0.71      0.34      0.46        44
#
#    micro avg       0.98      0.98      0.98      1939
#    macro avg       0.85      0.67      0.73      1939
# weighted avg       0.98      0.98      0.98      1939
#
# [[1889    6]
#  [  29   15]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp

probs = logmodel.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic for Logistic Regression')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1.1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
probs = rfc.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic for Random Forest')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1.1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
probs = logmodelx.predict_proba(X_testx)
preds = probs[:,1]
fpr, tpr, threshold = roc_curve(y_testx, preds)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic for Logistic Regression')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1.1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
probs = rfcx.predict_proba(X_testx)
preds = probs[:,1]
fpr, tpr, threshold = roc_curve(y_testx, preds)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic for Random Forest')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1.1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
print("These are the scores\nLogistic: {}\nRandomForest: {}".format(
    logmodelx.score(X_testx,y_testx),rfcx.score(X_testx,y_testx)))
# Out:
# These are the scores
# Logistic: 0.9669932955131512
# RandomForest: 0.9819494584837545
